# %%
# %%time
from neko.core.network import Network
from neko._visual.visualize_network import NetworkVisualizer
from neko._inputs.resources import Resources
from neko._annotations.gene_ontology import Ontology
import omnipath as op
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/Git/neko/neko/__init__.py in <module>
#      23 ]
#      24
# ---> 25 from ._metadata import __author__, __version__
#
# ~/Documents/Git/neko/neko/_metadata.py in <module>
#      22 import os
#      23 import pathlib
# ---> 24 import importlib.metadata
#      25
#      26 import toml
#
# ModuleNotFoundError: No module named 'importlib.metadata'

# %% [markdown]
# ### First we define a set of node we are interested in

# %%
genes = ['NME1', 'AXL', 'LAMC2', 'CDH5', 'HIF1A', 'EPHA2', 'EPAS1']
genes = ['PIK3CA', 'FOXO3', 'E2F1', 'MAPK1', 'AKT1']

# %%
genes = ['AKT1', 'JUN', 'FOS', 'APAF1', 'APC', 'AXIN1', 'BAD', 'BAK', 'BAX', 'BCL2', 
    'BCL2L1', 'BCL2L11', 'BID', 'BIRC5', 'CASP2', 'CASP3', 'CASP9', 'CDC25', 
    'CDKN1A', 'CDKN1B', 'CDKN2A', 'CREB1', 'CTNNB1', 'CYCS', 'CCNB1', 'CDK1', 
    'CCND1', 'CDK4', 'CDK6', 'CCNE1', 'CDK2', 'DIABLO', 'E2F1', 'E2F2', 'MAPK1', 
    'MAPK3', 'FOXO3', 'GSK3A', 'GSK3B', 'IKBKB', 'MAPK10', 'MAPK8', 'MAPK9', 'LEF1', 
    'MCL1', 'MDM2', 'MAP2K1', 'MAP2K2', 'MYC', 'NFKB1', 'NFKBIA', 'PRKACA', 'RB1', 
    'RPS6KA1', 'RPS6KA2', 'RPS6KA3', 'RPS6KA4', 'RPS6KA5', 'SMAD3', 'STAT1', 'STAT3', 
    'STAT5', 'TP53', 'XIAP', 'AKT1S1', 'DEPTOR', 'MLST8', 'RPTOR', 'MTOR', 'MAPK11', 
    'MAPK12', 'MAPK13', 'MAPK14', 'PKMYT1', 'DUSP1', 'CCNA1', 'BRAF', 'KRAS', 'EGFR', 
    'FOXO1', 'NFKBIA', 'PIK3CA', 'RICTOR']

# %% [markdown]
# ### Next we create a network using as input the gene set. Note that if no resource is specified, the default used resource by the package is omnipath.all_interactions()

# %%
resources = Resources()
#resources.import_signor_tsv("./all_data_18_03_24.tsv")

# %%
# %%time
new_net1 = Network(genes, resources=resources.interactions)
# Out:
# Loading deafault omnipath all interactions
# CPU times: user 2.54 s, sys: 97 ms, total: 2.64 s
# Wall time: 2.7 s

# %%
visualizer = NetworkVisualizer(new_net1, color_by='effect')
visualizer.render()

# %% [markdown]
# ### Now we can explore if the nodes are connected without introducing new bridge nodes

# %%
# %%time
new_net1.connect_nodes(only_signed=True)
# Out:
# P31749 Q92934
# P31749 Q07812
# P31749 O43521
# P42574 P31749
# P31749 P55211
# P31749 P38936
# P31749 P46527
# P31749 P16220
# P31749 P35222
# P31749 P24941
# P31749 O43524
# P31749 P49840
# P49840 P31749
# P31749 P49841
# P31749 O14920
# P45983 P31749
# P31749 Q00987
# P31749 P17612
# P31749 P84022
# P31749 P98170
# Q15418 P49841
# P49841 P84022
# P49841 P04637
# P49841 Q16539
# Q16539 P49841
# O14920 P19838
# O14920 P25963
# P53779 Q07820
# P53779 P04637
# P45983 P45984
# P45983 Q07820
# P45983 P01106
# P45983 P84022
# P45983 P42224
# P45983 P40763
# P40763 P45983
# P45983 P42229
# P45983 P04637
# P45983 Q99640
# P28562 P45983
# P45984 P01106
# P45984 P42224
# P45984 P40763
# P45984 P04637
# P28562 P45984
# P84022 Q9UJU2
# P04637 Q07820
# Q00987 P04637
# P04637 Q00987
# Q02750 O75676
# P15056 Q02750
# P00533 Q02750
# P15056 P36507
# P01106 P84022
# P42224 P01106
# Q16539 P01106
# P19838 P25963
# P25963 P19838
# P17612 P19838
# Q15349 P25963
# Q16539 P25963
# P17612 P42345
# Q16539 P17612
# P17612 P15056
# P04637 P06400
# Q16539 P06400
# Q15418 Q8TB45
# Q15418 Q8N122
# P42345 Q15349
# P51812 Q8N122
# Q16539 O75676
# O75582 P40763
# Q15759 O75582
# Q16539 O75582
# Q16539 P84022
# P84022 Q12778
# Q15759 P42224
# Q16539 P42224
# P00533 P42224
# P42345 P40763
# Q16539 P40763
# P00533 P40763
# Q12778 P40763
# P00533 P42229
# Q15759 P04637
# O15264 P04637
# Q16539 P04637
# P04637 P28562
# P04637 P00533
# Q96B36 Q8N122
# Q96B36 P42345
# P42345 Q96B36
# Q8TB45 P42345
# P42345 Q8TB45
# Q9BVC4 P42345
# Q8N122 P42345
# P42345 Q8N122
# Q15759 P00533
# Q16539 P28562
# P28562 Q16539
# Q16539 P00533
# P01116 P15056
# P01116 P42336
# CPU times: user 1min 16s, sys: 344 ms, total: 1min 16s
# Wall time: 1min 17s

# %% [markdown]
# ### We can visualize the network with the following command. The network is also exported in the working repository

# %%
visualizer = NetworkVisualizer(new_net1, color_by='effect')
visualizer.render()

# %% [markdown]
# ### We can also visualize the direct neighbors of pre-selected nodes of interest.

# %%
visualizer = NetworkVisualizer(new_net1, predefined_node="FOXO3",color_by='effect')
visualizer.render()

# %% [markdown]
# ### Overlay tissue expression information
#
# With this function the Annotation db is used to access tissue expression data from the Human Protein Atlas. The user can select a tissue of interest and the function will highlight those nodes that are expressed in the selected tissue.

# %%
genes_df = new_net1.nodes # extract node names

# %%
annot = Ontology()
#user_defined_tissue = 'breast cancer'
results_df = annot.check_tissue_annotations(genes_df = genes_df, tissue = 'breast cancer')
print(results_df)
# Out:
#    Genesymbol  in_tissue
# 0        AKT1       True
# 1         JUN       True
# 2         FOS       True
# 3       APAF1       True
# 4         APC       True
# ..        ...        ...
# 77       KRAS       True
# 78       EGFR       True
# 79      FOXO1       True
# 80     PIK3CA       True
# 81     RICTOR       True
#
# [82 rows x 2 columns]

# %%
network_visualizer = NetworkVisualizer(new_net1)
network_visualizer.tissue_mapping(results_df)
network_visualizer.render()

# %%
list(new_net1.nodes["Uniprot"])
# Out:
# ['P15531', 'P30530', 'Q13753', 'P33151', 'Q16665', 'P29317', 'Q99814']

# %% [markdown]
# ### We can try to connect the disconnected components using the following function. Be careful that the parameter maxlen is used to verify that in the network all the nodes have a distance < than maxlen. The parameter only_signed forces the algorithm to look for just signed intercations. Consensus retrieve those interactions with consensus between the references. Finally, connect_node_when_first_introduced, changes the base algorithm, making it look for possible connection between all the disconnected node in the network when a new bridge-gene is introduced in the network.

# %%
new_net1.add_node("RB1")

# %%
# %%time
new_net1.complete_connection(mode="ALL", maxlen=4, k_mean="extensive", only_signed=True, connect_node_when_first_introduced=True)
# Out:
# looking for paths in the network with length:  0  for node  AKT1  and  JUN
# looking for paths in the network with length:  1  for node  AKT1  and  JUN
# looking for paths in the network with length:  2  for node  AKT1  and  JUN
# Found a path!
# [['AKT1', 'GSK3A', 'JUN'], ['AKT1', 'GSK3B', 'JUN'], ['AKT1', 'SMAD3', 'JUN']]
# looking for paths in the network with length:  0  for node  AKT1  and  FOS
# looking for paths in the network with length:  1  for node  AKT1  and  FOS
# looking for paths in the network with length:  2  for node  AKT1  and  FOS
# Found a path!
# [['AKT1', 'PRKACA', 'FOS']]
# looking for paths in the network with length:  0  for node  AKT1  and  APAF1
# looking for paths in the network with length:  1  for node  AKT1  and  APAF1
# looking for paths in the network with length:  2  for node  AKT1  and  APAF1
# Found a path!
# [['AKT1', 'BAX', 'APAF1']]
# looking for paths in the network with length:  0  for node  AKT1  and  APC
# looking for paths in the network with length:  1  for node  AKT1  and  APC
# looking for paths in the network with length:  2  for node  AKT1  and  APC
# Found a path!
# [['AKT1', 'GSK3B', 'APC'], ['AKT1', 'PRKACA', 'APC']]
# looking for paths in the network with length:  0  for node  AKT1  and  AXIN1
# looking for paths in the network with length:  1  for node  AKT1  and  AXIN1
# looking for paths in the network with length:  2  for node  AKT1  and  AXIN1
# Found a path!
# [['AKT1', 'GSK3B', 'AXIN1'], ['AKT1', 'CDK2', 'AXIN1'], ['AKT1', 'GSK3A', 'AXIN1']]
# looking for paths in the network with length:  0  for node  AKT1  and  BAD
# looking for paths in the network with length:  1  for node  AKT1  and  BAD
# Found a path!
# [['AKT1', 'BAD']]
# looking for paths in the network with length:  0  for node  AKT1  and  BAK1
# looking for paths in the network with length:  1  for node  AKT1  and  BAK1
# looking for paths in the network with length:  2  for node  AKT1  and  BAK1
# Found a path!
# [['AKT1', 'BCL2L11', 'BAK1']]
# looking for paths in the network with length:  0  for node  AKT1  and  BAX
# looking for paths in the network with length:  1  for node  AKT1  and  BAX
# Found a path!
# [['AKT1', 'BAX']]
# looking for paths in the network with length:  0  for node  AKT1  and  BCL2
# looking for paths in the network with length:  1  for node  AKT1  and  BCL2
# looking for paths in the network with length:  2  for node  AKT1  and  BCL2
# Found a path!
# [['AKT1', 'BAD', 'BCL2'], ['AKT1', 'BCL2L11', 'BCL2'], ['AKT1', 'BAX', 'BCL2']]
# looking for paths in the network with length:  0  for node  AKT1  and  BCL2L1
# looking for paths in the network with length:  1  for node  AKT1  and  BCL2L1
# looking for paths in the network with length:  2  for node  AKT1  and  BCL2L1
# Found a path!
# [['AKT1', 'BAD', 'BCL2L1'], ['AKT1', 'BCL2L11', 'BCL2L1']]
# looking for paths in the network with length:  0  for node  AKT1  and  BCL2L11
# looking for paths in the network with length:  1  for node  AKT1  and  BCL2L11
# Found a path!
# [['AKT1', 'BCL2L11']]
# looking for paths in the network with length:  0  for node  AKT1  and  BID
# looking for paths in the network with length:  1  for node  AKT1  and  BID
# looking for paths in the network with length:  2  for node  AKT1  and  BID
# looking for paths in the network with length:  3  for node  AKT1  and  BID
# Found a path!
# [['AKT1', 'GSK3B', 'TP53', 'BID'], ['AKT1', 'BAD', 'BCL2', 'BID'], ['AKT1', 'BAD', 'TP53', 'BID'], ['AKT1', 'BAD', 'BCL2L1', 'BID'], ['AKT1', 'MDM2', 'TP53', 'BID'], ['AKT1', 'BCL2L11', 'BCL2', 'BID'], ['AKT1', 'BCL2L11', 'BCL2L1', 'BID'], ['AKT1', 'CDK2', 'TP53', 'BID'], ['AKT1', 'BAX', 'BCL2', 'BID']]
# looking for paths in the network with length:  0  for node  AKT1  and  BIRC5
# looking for paths in the network with length:  1  for node  AKT1  and  BIRC5
# looking for paths in the network with length:  2  for node  AKT1  and  BIRC5
# Found a path!
# [['AKT1', 'CASP3', 'BIRC5']]
# looking for paths in the network with length:  0  for node  AKT1  and  CASP2
# looking for paths in the network with length:  1  for node  AKT1  and  CASP2
# looking for paths in the network with length:  2  for node  AKT1  and  CASP2
# looking for paths in the network with length:  3  for node  AKT1  and  CASP2
# Found a path!
# [['AKT1', 'CASP9', 'CASP3', 'CASP2'], ['AKT1', 'XIAP', 'CASP3', 'CASP2']]
# looking for paths in the network with length:  0  for node  AKT1  and  CASP3
# looking for paths in the network with length:  1  for node  AKT1  and  CASP3
# Found a path!
# [['AKT1', 'CASP3']]
# looking for paths in the network with length:  0  for node  AKT1  and  CASP9
# looking for paths in the network with length:  1  for node  AKT1  and  CASP9
# Found a path!
# [['AKT1', 'CASP9']]
# looking for paths in the network with length:  0  for node  AKT1  and  RASGRF1
# looking for paths in the network with length:  1  for node  AKT1  and  RASGRF1
# looking for paths in the network with length:  2  for node  AKT1  and  RASGRF1
# Found a path!
# [['AKT1', 'PRKACA', 'RASGRF1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDKN1A
# looking for paths in the network with length:  1  for node  AKT1  and  CDKN1A
# Found a path!
# [['AKT1', 'CDKN1A']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDKN1B
# looking for paths in the network with length:  1  for node  AKT1  and  CDKN1B
# Found a path!
# [['AKT1', 'CDKN1B']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDKN2A
# looking for paths in the network with length:  1  for node  AKT1  and  CDKN2A
# looking for paths in the network with length:  2  for node  AKT1  and  CDKN2A
# Found a path!
# [['AKT1', 'IKBKB', 'CDKN2A']]
# looking for paths in the network with length:  0  for node  AKT1  and  CREB1
# looking for paths in the network with length:  1  for node  AKT1  and  CREB1
# Found a path!
# [['AKT1', 'CREB1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CTNNB1
# looking for paths in the network with length:  1  for node  AKT1  and  CTNNB1
# Found a path!
# [['AKT1', 'CTNNB1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CYCS
# looking for paths in the network with length:  1  for node  AKT1  and  CYCS
# looking for paths in the network with length:  2  for node  AKT1  and  CYCS
# Found a path!
# [['AKT1', 'GSK3B', 'CYCS'], ['AKT1', 'BAD', 'CYCS'], ['AKT1', 'BAX', 'CYCS']]
# looking for paths in the network with length:  0  for node  AKT1  and  CCNB1
# looking for paths in the network with length:  1  for node  AKT1  and  CCNB1
# looking for paths in the network with length:  2  for node  AKT1  and  CCNB1
# Found a path!
# [['AKT1', 'CDKN1A', 'CCNB1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDK1
# looking for paths in the network with length:  1  for node  AKT1  and  CDK1
# looking for paths in the network with length:  2  for node  AKT1  and  CDK1
# Found a path!
# [['AKT1', 'CDKN1A', 'CDK1'], ['AKT1', 'GSK3B', 'CDK1'], ['AKT1', 'CDKN1B', 'CDK1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CCND1
# looking for paths in the network with length:  1  for node  AKT1  and  CCND1
# looking for paths in the network with length:  2  for node  AKT1  and  CCND1
# Found a path!
# [['AKT1', 'GSK3B', 'CCND1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDK4
# looking for paths in the network with length:  1  for node  AKT1  and  CDK4
# looking for paths in the network with length:  2  for node  AKT1  and  CDK4
# Found a path!
# [['AKT1', 'CDKN1A', 'CDK4']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDK6
# looking for paths in the network with length:  1  for node  AKT1  and  CDK6
# looking for paths in the network with length:  2  for node  AKT1  and  CDK6
# Found a path!
# [['AKT1', 'CDKN1A', 'CDK6'], ['AKT1', 'CREB1', 'CDK6']]
# looking for paths in the network with length:  0  for node  AKT1  and  CCNE1
# looking for paths in the network with length:  1  for node  AKT1  and  CCNE1
# looking for paths in the network with length:  2  for node  AKT1  and  CCNE1
# Found a path!
# [['AKT1', 'GSK3B', 'CCNE1'], ['AKT1', 'CDK2', 'CCNE1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CDK2
# looking for paths in the network with length:  1  for node  AKT1  and  CDK2
# Found a path!
# [['AKT1', 'CDK2']]
# looking for paths in the network with length:  0  for node  AKT1  and  DIABLO
# looking for paths in the network with length:  1  for node  AKT1  and  DIABLO
# looking for paths in the network with length:  2  for node  AKT1  and  DIABLO
# Found a path!
# [['AKT1', 'XIAP', 'DIABLO'], ['AKT1', 'BAX', 'DIABLO']]
# looking for paths in the network with length:  0  for node  AKT1  and  E2F1
# looking for paths in the network with length:  1  for node  AKT1  and  E2F1
# looking for paths in the network with length:  2  for node  AKT1  and  E2F1
# Found a path!
# [['AKT1', 'CDK2', 'E2F1'], ['AKT1', 'CASP3', 'E2F1']]
# looking for paths in the network with length:  0  for node  AKT1  and  E2F2
# looking for paths in the network with length:  1  for node  AKT1  and  E2F2
# looking for paths in the network with length:  2  for node  AKT1  and  E2F2
# looking for paths in the network with length:  3  for node  AKT1  and  E2F2
# Found a path!
# [['AKT1', 'CDK2', 'RB1', 'E2F2']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK1
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK1
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK1
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1'], ['AKT1', 'PRKACA', 'MAPK1']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK3
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK3
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK3
# Found a path!
# [['AKT1', 'BRAF', 'MAPK3']]
# looking for paths in the network with length:  0  for node  AKT1  and  FOXO3
# looking for paths in the network with length:  1  for node  AKT1  and  FOXO3
# Found a path!
# [['AKT1', 'FOXO3']]
# looking for paths in the network with length:  0  for node  AKT1  and  GSK3A
# looking for paths in the network with length:  1  for node  AKT1  and  GSK3A
# Found a path!
# [['AKT1', 'GSK3A'], ['AKT1', 'GSK3A']]
# looking for paths in the network with length:  0  for node  AKT1  and  GSK3B
# looking for paths in the network with length:  1  for node  AKT1  and  GSK3B
# Found a path!
# [['AKT1', 'GSK3B']]
# looking for paths in the network with length:  0  for node  AKT1  and  IKBKB
# looking for paths in the network with length:  1  for node  AKT1  and  IKBKB
# Found a path!
# [['AKT1', 'IKBKB']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK10
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK10
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK10
# looking for paths in the network with length:  3  for node  AKT1  and  MAPK10
# looking for paths in the network with length:  4  for node  AKT1  and  MAPK10
# Found a path!
# [['AKT1', 'MAPK8', 'DUSP1', 'TP53', 'MAPK10'], ['AKT1', 'CASP3', 'XIAP', 'DIABLO', 'MAPK10'], ['AKT1', 'CASP3', 'BIRC5', 'DIABLO', 'MAPK10'], ['AKT1', 'CASP3', 'BIRC5', 'TP53', 'MAPK10']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK8
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK8
# Found a path!
# [['AKT1', 'MAPK8']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK9
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK9
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK9
# looking for paths in the network with length:  3  for node  AKT1  and  MAPK9
# Found a path!
# [['AKT1', 'MAPK8', 'STAT3', 'MAPK9']]
# looking for paths in the network with length:  0  for node  AKT1  and  LEF1
# looking for paths in the network with length:  1  for node  AKT1  and  LEF1
# looking for paths in the network with length:  2  for node  AKT1  and  LEF1
# Found a path!
# [['AKT1', 'CTNNB1', 'LEF1'], ['AKT1', 'SMAD3', 'LEF1']]
# looking for paths in the network with length:  0  for node  AKT1  and  MCL1
# looking for paths in the network with length:  1  for node  AKT1  and  MCL1
# looking for paths in the network with length:  2  for node  AKT1  and  MCL1
# Found a path!
# [['AKT1', 'GSK3A', 'MCL1'], ['AKT1', 'GSK3B', 'MCL1'], ['AKT1', 'BCL2L11', 'MCL1']]
# looking for paths in the network with length:  0  for node  AKT1  and  MDM2
# looking for paths in the network with length:  1  for node  AKT1  and  MDM2
# Found a path!
# [['AKT1', 'MDM2']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAP2K1
# looking for paths in the network with length:  1  for node  AKT1  and  MAP2K1
# looking for paths in the network with length:  2  for node  AKT1  and  MAP2K1
# Found a path!
# [['AKT1', 'BRAF', 'MAP2K1'], ['AKT1', 'GSK3B', 'MAP2K1']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAP2K2
# looking for paths in the network with length:  1  for node  AKT1  and  MAP2K2
# looking for paths in the network with length:  2  for node  AKT1  and  MAP2K2
# Found a path!
# [['AKT1', 'BRAF', 'MAP2K2']]
# looking for paths in the network with length:  0  for node  AKT1  and  MYC
# looking for paths in the network with length:  1  for node  AKT1  and  MYC
# looking for paths in the network with length:  2  for node  AKT1  and  MYC
# Found a path!
# [['AKT1', 'CREB1', 'MYC'], ['AKT1', 'GSK3A', 'MYC'], ['AKT1', 'GSK3B', 'MYC'], ['AKT1', 'CDK2', 'MYC']]
# looking for paths in the network with length:  0  for node  AKT1  and  NFKB1
# looking for paths in the network with length:  1  for node  AKT1  and  NFKB1
# looking for paths in the network with length:  2  for node  AKT1  and  NFKB1
# Found a path!
# [['AKT1', 'IKBKB', 'NFKB1'], ['AKT1', 'GSK3B', 'NFKB1'], ['AKT1', 'PRKACA', 'NFKB1']]
# looking for paths in the network with length:  0  for node  AKT1  and  NFKBIA
# looking for paths in the network with length:  1  for node  AKT1  and  NFKBIA
# looking for paths in the network with length:  2  for node  AKT1  and  NFKBIA
# Found a path!
# [['AKT1', 'IKBKB', 'NFKBIA']]
# looking for paths in the network with length:  0  for node  AKT1  and  PRKACA
# looking for paths in the network with length:  1  for node  AKT1  and  PRKACA
# Found a path!
# [['AKT1', 'PRKACA']]
# looking for paths in the network with length:  0  for node  AKT1  and  RB1
# looking for paths in the network with length:  1  for node  AKT1  and  RB1
# looking for paths in the network with length:  2  for node  AKT1  and  RB1
# Found a path!
# [['AKT1', 'CDK2', 'RB1']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPS6KA1
# looking for paths in the network with length:  1  for node  AKT1  and  RPS6KA1
# looking for paths in the network with length:  2  for node  AKT1  and  RPS6KA1
# looking for paths in the network with length:  3  for node  AKT1  and  RPS6KA1
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1', 'RPS6KA1'], ['AKT1', 'BRAF', 'MAPK3', 'RPS6KA1'], ['AKT1', 'PRKACA', 'MAPK1', 'RPS6KA1'], ['AKT1', 'MTOR', 'DEPTOR', 'RPS6KA1'], ['AKT1', 'MTOR', 'RPTOR', 'RPS6KA1']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPS6KA2
# looking for paths in the network with length:  1  for node  AKT1  and  RPS6KA2
# looking for paths in the network with length:  2  for node  AKT1  and  RPS6KA2
# Found a path!
# [['AKT1', 'MTOR', 'RPS6KA2']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPS6KA3
# looking for paths in the network with length:  1  for node  AKT1  and  RPS6KA3
# looking for paths in the network with length:  2  for node  AKT1  and  RPS6KA3
# Found a path!
# [['AKT1', 'GSK3A', 'RPS6KA3']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPS6KA4
# looking for paths in the network with length:  1  for node  AKT1  and  RPS6KA4
# looking for paths in the network with length:  2  for node  AKT1  and  RPS6KA4
# looking for paths in the network with length:  3  for node  AKT1  and  RPS6KA4
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1', 'RPS6KA4'], ['AKT1', 'BRAF', 'MAP2K1', 'RPS6KA4'], ['AKT1', 'BRAF', 'MAPK3', 'RPS6KA4'], ['AKT1', 'GSK3B', 'MAP2K1', 'RPS6KA4'], ['AKT1', 'GSK3B', 'MAPK14', 'RPS6KA4'], ['AKT1', 'PRKACA', 'MAPK1', 'RPS6KA4']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPS6KA5
# looking for paths in the network with length:  1  for node  AKT1  and  RPS6KA5
# looking for paths in the network with length:  2  for node  AKT1  and  RPS6KA5
# looking for paths in the network with length:  3  for node  AKT1  and  RPS6KA5
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1', 'RPS6KA5'], ['AKT1', 'BRAF', 'MAPK3', 'RPS6KA5'], ['AKT1', 'GSK3B', 'MAPK14', 'RPS6KA5'], ['AKT1', 'PRKACA', 'MAPK1', 'RPS6KA5'], ['AKT1', 'MAPK8', 'STAT3', 'RPS6KA5']]
# looking for paths in the network with length:  0  for node  AKT1  and  SMAD3
# looking for paths in the network with length:  1  for node  AKT1  and  SMAD3
# Found a path!
# [['AKT1', 'SMAD3']]
# looking for paths in the network with length:  0  for node  AKT1  and  STAT1
# looking for paths in the network with length:  1  for node  AKT1  and  STAT1
# looking for paths in the network with length:  2  for node  AKT1  and  STAT1
# looking for paths in the network with length:  3  for node  AKT1  and  STAT1
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1', 'STAT1'], ['AKT1', 'GSK3B', 'MAPK14', 'STAT1'], ['AKT1', 'PRKACA', 'MAPK1', 'STAT1']]
# looking for paths in the network with length:  0  for node  AKT1  and  STAT3
# looking for paths in the network with length:  1  for node  AKT1  and  STAT3
# looking for paths in the network with length:  2  for node  AKT1  and  STAT3
# Found a path!
# [['AKT1', 'MTOR', 'STAT3'], ['AKT1', 'FOXO1', 'STAT3'], ['AKT1', 'MAPK8', 'STAT3']]
# looking for paths in the network with length:  0  for node  AKT1  and  STAT5A
# looking for paths in the network with length:  1  for node  AKT1  and  STAT5A
# looking for paths in the network with length:  2  for node  AKT1  and  STAT5A
# looking for paths in the network with length:  3  for node  AKT1  and  STAT5A
# Found a path!
# [['AKT1', 'BRAF', 'MAPK1', 'STAT5A'], ['AKT1', 'BRAF', 'MAPK3', 'STAT5A'], ['AKT1', 'PRKACA', 'MAPK1', 'STAT5A']]
# looking for paths in the network with length:  0  for node  AKT1  and  TP53
# looking for paths in the network with length:  1  for node  AKT1  and  TP53
# looking for paths in the network with length:  2  for node  AKT1  and  TP53
# Found a path!
# [['AKT1', 'GSK3B', 'TP53'], ['AKT1', 'BAD', 'TP53'], ['AKT1', 'MDM2', 'TP53'], ['AKT1', 'CDK2', 'TP53']]
# looking for paths in the network with length:  0  for node  AKT1  and  XIAP
# looking for paths in the network with length:  1  for node  AKT1  and  XIAP
# Found a path!
# [['AKT1', 'XIAP']]
# looking for paths in the network with length:  0  for node  AKT1  and  AKT1S1
# looking for paths in the network with length:  1  for node  AKT1  and  AKT1S1
# Found a path!
# [['AKT1', 'AKT1S1']]
# looking for paths in the network with length:  0  for node  AKT1  and  DEPTOR
# looking for paths in the network with length:  1  for node  AKT1  and  DEPTOR
# looking for paths in the network with length:  2  for node  AKT1  and  DEPTOR
# Found a path!
# [['AKT1', 'MTOR', 'DEPTOR'], ['AKT1', 'MTOR', 'DEPTOR']]
# looking for paths in the network with length:  0  for node  AKT1  and  MLST8
# looking for paths in the network with length:  1  for node  AKT1  and  MLST8
# looking for paths in the network with length:  2  for node  AKT1  and  MLST8
# Found a path!
# [['AKT1', 'MTOR', 'MLST8']]
# looking for paths in the network with length:  0  for node  AKT1  and  RPTOR
# looking for paths in the network with length:  1  for node  AKT1  and  RPTOR
# looking for paths in the network with length:  2  for node  AKT1  and  RPTOR
# Found a path!
# [['AKT1', 'MTOR', 'RPTOR'], ['AKT1', 'AKT1S1', 'RPTOR'], ['AKT1', 'MTOR', 'RPTOR']]
# looking for paths in the network with length:  0  for node  AKT1  and  MTOR
# looking for paths in the network with length:  1  for node  AKT1  and  MTOR
# Found a path!
# [['AKT1', 'MTOR'], ['AKT1', 'MTOR']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK11
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK11
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK11
# looking for paths in the network with length:  3  for node  AKT1  and  MAPK11
# looking for paths in the network with length:  4  for node  AKT1  and  MAPK11
# Found a path!
# [['AKT1', 'MAPK8', 'STAT3', 'RPS6KA5', 'MAPK11'], ['AKT1', 'MAPK8', 'STAT3', 'EGFR', 'MAPK11'], ['AKT1', 'MAPK8', 'DUSP1', 'TP53', 'MAPK11'], ['AKT1', 'CASP3', 'BIRC5', 'TP53', 'MAPK11'], ['AKT1', 'CASP3', 'E2F1', 'EGFR', 'MAPK11']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK12
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK12
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK12
# Found a path!
# [['AKT1', 'MAP2K4', 'MAPK12']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK13
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK13
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK13
# looking for paths in the network with length:  3  for node  AKT1  and  MAPK13
# looking for paths in the network with length:  4  for node  AKT1  and  MAPK13
# Found a path!
# [['AKT1', 'MAPK8', 'DUSP1', 'TP53', 'MAPK13'], ['AKT1', 'CASP3', 'BIRC5', 'TP53', 'MAPK13']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAPK14
# looking for paths in the network with length:  1  for node  AKT1  and  MAPK14
# looking for paths in the network with length:  2  for node  AKT1  and  MAPK14
# Found a path!
# [['AKT1', 'GSK3B', 'MAPK14'], ['AKT1', 'CASP3', 'MAPK14']]
# looking for paths in the network with length:  0  for node  AKT1  and  PKMYT1
# looking for paths in the network with length:  1  for node  AKT1  and  PKMYT1
# looking for paths in the network with length:  2  for node  AKT1  and  PKMYT1
# looking for paths in the network with length:  3  for node  AKT1  and  PKMYT1
# looking for paths in the network with length:  4  for node  AKT1  and  PKMYT1
# Found a path!
# [['AKT1', 'MTOR', 'STAT3', 'MAPK8', 'PKMYT1'], ['AKT1', 'FOXO1', 'STAT3', 'MAPK8', 'PKMYT1'], ['AKT1', 'CASP3', 'BIRC5', 'CDK1', 'PKMYT1'], ['AKT1', 'CASP3', 'CASP9', 'CDK1', 'PKMYT1'], ['AKT1', 'CASP3', 'E2F1', 'CDK1', 'PKMYT1']]
# looking for paths in the network with length:  0  for node  AKT1  and  DUSP1
# looking for paths in the network with length:  1  for node  AKT1  and  DUSP1
# looking for paths in the network with length:  2  for node  AKT1  and  DUSP1
# Found a path!
# [['AKT1', 'MAPK8', 'DUSP1']]
# looking for paths in the network with length:  0  for node  AKT1  and  CCNA1
# looking for paths in the network with length:  1  for node  AKT1  and  CCNA1
# looking for paths in the network with length:  2  for node  AKT1  and  CCNA1
# looking for paths in the network with length:  3  for node  AKT1  and  CCNA1
# Found a path!
# [['AKT1', 'CASP3', 'E2F1', 'CCNA1']]
# looking for paths in the network with length:  0  for node  AKT1  and  BRAF
# looking for paths in the network with length:  1  for node  AKT1  and  BRAF
# Found a path!
# [['AKT1', 'BRAF']]
# looking for paths in the network with length:  0  for node  AKT1  and  KRAS
# looking for paths in the network with length:  1  for node  AKT1  and  KRAS
# looking for paths in the network with length:  2  for node  AKT1  and  KRAS
# looking for paths in the network with length:  3  for node  AKT1  and  KRAS
# looking for paths in the network with length:  4  for node  AKT1  and  KRAS
# i_search =  4
# Looking for paths with length:  0  for node  AKT1  and  KRAS
# i_search =  4
# Looking for paths with length:  1  for node  AKT1  and  KRAS
# i_search =  4
# Looking for paths with length:  2  for node  AKT1  and  KRAS
# [['AKT1', 'DAB2IP', 'KRAS'], ['AKT1', 'SRC', 'KRAS'], ['AKT1', 'COMPLEX:P27986_P42336', 'KRAS']]
# P31749 Q5VWQ8
# Q5VWQ8 P01116
# P31749 P12931
# P12931 P01116
# COMPLEX:P27986_P42336 P31749
# P01116 COMPLEX:P27986_P42336
# P31749 Q92934
# P31749 Q07812
# P31749 O43521
# P42574 P31749
# P31749 P55211
# P31749 P38936
# P31749 P46527
# P31749 P16220
# P31749 P35222
# P31749 P24941
# P31749 O43524
# P31749 P49840
# P49840 P31749
# P31749 P49841
# P31749 O14920
# P45983 P31749
# P31749 Q00987
# P15056 P27361
# P27361 P00533
# O14920 O43524
# Q16539 O43524
# O43524 P42336
# P49840 Q07820
# P49840 P01106
# P17612 P49840
# P51812 P49840
# P49841 Q07820
# P49841 Q00987
# P49841 Q02750
# Q02750 P49841
# P49841 P01106
# P49841 P19838
# P17612 P49841
# Q15418 P49841
# P49841 P84022
# P49841 P04637
# P49841 Q16539
# Q16539 P49841
# Q5VWQ8 P49841
# O14920 P19838
# O14920 P25963
# P12931 O14920
# P53779 Q07820
# P53779 P04637
# P45985 P53779
# P45983 P45984
# P45983 Q07820
# P45983 P01106
# P45983 P84022
# P45983 P42224
# P45983 P40763
# P40763 P45983
# P45983 P42229
# P45983 P04637
# P45983 Q99640
# P28562 P45983
# P45985 P45983
# P45983 P12931
# P45984 P01106
# P45984 P42224
# P45984 P40763
# P45984 P04637
# P28562 P45984
# P45985 P45984
# P84022 Q9UJU2
# P04637 Q07820
# Q00987 P04637
# P04637 Q00987
# Q02750 O75676
# P15056 Q02750
# P00533 Q02750
# P15056 P36507
# P01106 P84022
# P42224 P01106
# Q16539 P01106
# P19838 P25963
# P25963 P19838
# P17612 P19838
# Q15349 P25963
# Q16539 P25963
# P12931 P25963
# P17612 P42345
# Q16539 P17612
# P17612 P15056
# P17612 P12931
# P12931 P17612
# P04637 P06400
# Q16539 P06400
# Q15418 Q8TB45
# Q15418 Q8N122
# P42345 Q15349
# P51812 Q8N122
# P12931 P51812
# Q16539 O75676
# O75582 P40763
# Q15759 O75582
# Q16539 O75582
# Q16539 P84022
# P84022 Q12778
# Q15759 P42224
# Q16539 P42224
# P00533 P42224
# P12931 P42224
# P42345 P40763
# Q16539 P40763
# P00533 P40763
# Q12778 P40763
# Q5VWQ8 P40763
# P40763 P12931
# P12931 P40763
# P00533 P42229
# P12931 P42229
# Q15759 P04637
# O15264 P04637
# Q16539 P04637
# P04637 P28562
# P04637 P00533
# Q96B36 Q8N122
# Q96B36 P42345
# P42345 Q96B36
# Q8TB45 P42345
# P42345 Q8TB45
# Q9BVC4 P42345
# Q8N122 P42345
# P42345 Q8N122
# Q15759 P00533
# P45985 P53778
# Q16539 P28562
# P28562 Q16539
# Q16539 P00533
# P45985 Q16539
# P01116 P15056
# P01116 P42336
# Q5VWQ8 P01116
# P12931 P01116
# P01116 COMPLEX:P27986_P42336
# P12931 P00533
# P00533 COMPLEX:P27986_P42336
# Q5VWQ8 P42336
# P42336 P12931
# P12931 P42336
# looking for paths in the network with length:  0  for node  AKT1  and  EGFR
# looking for paths in the network with length:  1  for node  AKT1  and  EGFR
# looking for paths in the network with length:  2  for node  AKT1  and  EGFR
# Found a path!
# [['AKT1', 'SRC', 'EGFR'], ['AKT1', 'COMPLEX:P27986_P42336', 'EGFR']]
# looking for paths in the network with length:  0  for node  AKT1  and  FOXO1
# looking for paths in the network with length:  1  for node  AKT1  and  FOXO1
# Found a path!
# [['AKT1', 'FOXO1']]
# looking for paths in the network with length:  0  for node  AKT1  and  PIK3CA
# looking for paths in the network with length:  1  for node  AKT1  and  PIK3CA
# looking for paths in the network with length:  2  for node  AKT1  and  PIK3CA
# Found a path!
# [['AKT1', 'FOXO3', 'PIK3CA'], ['AKT1', 'SRC', 'PIK3CA'], ['AKT1', 'DAB2IP', 'PIK3CA'], ['AKT1', 'SRC', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  AKT1  and  RICTOR
# looking for paths in the network with length:  1  for node  AKT1  and  RICTOR
# Found a path!
# [['AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  AKT1  and  MAP2K4
# looking for paths in the network with length:  1  for node  AKT1  and  MAP2K4
# Found a path!
# [['AKT1', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  JUN  and  FOS
# looking for paths in the network with length:  1  for node  JUN  and  FOS
# Found a path!
# [['JUN', 'FOS']]
# looking for paths in the network with length:  0  for node  JUN  and  APAF1
# looking for paths in the network with length:  1  for node  JUN  and  APAF1
# looking for paths in the network with length:  2  for node  JUN  and  APAF1
# looking for paths in the network with length:  3  for node  JUN  and  APAF1
# looking for paths in the network with length:  4  for node  JUN  and  APAF1
# Found a path!
# [['JUN', 'CREB1', 'MYC', 'E2F1', 'APAF1']]
# looking for paths in the network with length:  0  for node  JUN  and  APC
# looking for paths in the network with length:  1  for node  JUN  and  APC
# looking for paths in the network with length:  2  for node  JUN  and  APC
# looking for paths in the network with length:  3  for node  JUN  and  APC
# looking for paths in the network with length:  4  for node  JUN  and  APC
# i_search =  4
# Looking for paths with length:  0  for node  JUN  and  APC
# i_search =  4
# Looking for paths with length:  1  for node  JUN  and  APC
# i_search =  4
# Looking for paths with length:  2  for node  JUN  and  APC
# i_search =  4
# Looking for paths with length:  3  for node  JUN  and  APC
# [['JUN', 'PPM1D', 'TP53', 'APC'], ['JUN', 'CREBBP', 'CTNNB1', 'APC']]
# P05412 O15297
# O15297 P04637
# P04637 P25054
# Q92793 P05412
# Q92793 P35222
# P25054 P35222
# P31749 Q92934
# P31749 Q07812
# P31749 O43521
# P42574 P31749
# P31749 P55211
# P31749 P38936
# P31749 P46527
# P31749 P16220
# P31749 P35222
# P31749 P24941
# P31749 O43524
# P31749 P49840
# P49840 P31749
# P31749 P49841
# P31749 O14920
# P45983 P31749
# P31749 Q00987
# P31749 P17612
# P31749 P84022
# P31749 P98170
# P31749 Q96B36
# P31749 P42345
# P42345 P31749
# P31749 P15056
# P31749 Q12778
# Q6R327 P31749
# P31749 P45985
# P31749 Q5VWQ8
# P31749 P12931
# P12931 P31749
# COMPLEX:P27986_P42336 P31749
# P01100 P05412
# P05412 P16220
# P05412 P35222
# P28482 P05412
# P27361 P05412
# P49840 P05412
# P49841 P05412
# P53779 P05412
# P45983 P05412
# P45984 P05412
# P05412 P84022
# P84022 P05412
# Q16539 P05412
# P05412 O15297
# Q92793 P05412
# P28482 P01100
# P27361 P01100
# P45984 P01100
# P17612 P01100
# Q15418 P01100
# P51812 P01100
# O75676 P01100
# Q16539 P01100
# P12931 P01100
# Q07812 O14727
# Q07817 O14727
# O14727 P55211
# P99999 O14727
# P45983 P42229
# P45983 P04637
# P45983 Q99640
# P28562 P45983
# P45985 P45983
# P45983 P12931
# P45984 P01106
# P45984 P42224
# P45984 P40763
# P45984 P04637
# P28562 P45984
# P45985 P45984
# P84022 Q9UJU2
# P04637 Q07820
# Q00987 P04637
# P04637 Q00987
# O15297 Q00987
# Q02750 O75676
# P15056 Q02750
# P00533 Q02750
# P15056 P36507
# P01106 P84022
# P42224 P01106
# Q16539 P01106
# P19838 P25963
# P25963 P19838
# P17612 P19838
# P19838 Q92793
# Q92793 P19838
# Q15349 P25963
# Q16539 P25963
# P12931 P25963
# P17612 P42345
# Q16539 P17612
# P17612 P15056
# P17612 P12931
# P12931 P17612
# P17612 Q92793
# P04637 P06400
# Q16539 P06400
# Q15418 Q8TB45
# Q15418 Q8N122
# P42345 Q15349
# P51812 Q8N122
# P12931 P51812
# O15297 P51812
# Q16539 O75676
# O75582 P40763
# Q15759 O75582
# Q16539 O75582
# Q16539 P84022
# P84022 Q12778
# Q92793 P84022
# Q15759 P42224
# Q16539 P42224
# P00533 P42224
# P12931 P42224
# P42224 Q92793
# P42345 P40763
# Q16539 P40763
# P00533 P40763
# Q12778 P40763
# Q5VWQ8 P40763
# P40763 P12931
# P12931 P40763
# Q92793 P40763
# P00533 P42229
# P12931 P42229
# Q15759 P04637
# O15264 P04637
# Q16539 P04637
# P04637 P28562
# P04637 P00533
# P04637 O15297
# O15297 P04637
# Q92793 P04637
# Q96B36 Q8N122
# Q96B36 P42345
# P42345 Q96B36
# Q8TB45 P42345
# P42345 Q8TB45
# Q9BVC4 P42345
# Q8N122 P42345
# P42345 Q8N122
# Q15759 P00533
# P45985 P53778
# O15297 P53778
# Q16539 P28562
# P28562 Q16539
# Q16539 P00533
# P45985 Q16539
# O15297 Q16539
# P01116 P15056
# P01116 P42336
# Q5VWQ8 P01116
# P12931 P01116
# P01116 COMPLEX:P27986_P42336
# P12931 P00533
# P00533 COMPLEX:P27986_P42336
# Q5VWQ8 P42336
# P42336 P12931
# P12931 P42336
# looking for paths in the network with length:  0  for node  JUN  and  AXIN1
# looking for paths in the network with length:  1  for node  JUN  and  AXIN1
# looking for paths in the network with length:  2  for node  JUN  and  AXIN1
# Found a path!
# [['JUN', 'SMAD3', 'AXIN1'], ['JUN', 'GSK3A', 'AXIN1'], ['JUN', 'GSK3B', 'AXIN1']]
# looking for paths in the network with length:  0  for node  JUN  and  BAD
# looking for paths in the network with length:  1  for node  JUN  and  BAD
# looking for paths in the network with length:  2  for node  JUN  and  BAD
# looking for paths in the network with length:  3  for node  JUN  and  BAD
# Found a path!
# [['JUN', 'PPM1D', 'RPS6KA3', 'BAD']]
# looking for paths in the network with length:  0  for node  JUN  and  BAK1
# looking for paths in the network with length:  1  for node  JUN  and  BAK1
# looking for paths in the network with length:  2  for node  JUN  and  BAK1
# looking for paths in the network with length:  3  for node  JUN  and  BAK1
# Found a path!
# [['JUN', 'PPM1D', 'TP53', 'BAK1']]
# looking for paths in the network with length:  0  for node  JUN  and  BAX
# looking for paths in the network with length:  1  for node  JUN  and  BAX
# looking for paths in the network with length:  2  for node  JUN  and  BAX
# looking for paths in the network with length:  3  for node  JUN  and  BAX
# Found a path!
# [['JUN', 'PPM1D', 'TP53', 'BAX']]
# looking for paths in the network with length:  0  for node  JUN  and  BCL2
# looking for paths in the network with length:  1  for node  JUN  and  BCL2
# looking for paths in the network with length:  2  for node  JUN  and  BCL2
# looking for paths in the network with length:  3  for node  JUN  and  BCL2
# Found a path!
# [['JUN', 'CREB1', 'CDK6', 'BCL2'], ['JUN', 'PPM1D', 'TP53', 'BCL2'], ['JUN', 'PPM1D', 'MAPK14', 'BCL2']]
# looking for paths in the network with length:  0  for node  JUN  and  BCL2L1
# looking for paths in the network with length:  1  for node  JUN  and  BCL2L1
# looking for paths in the network with length:  2  for node  JUN  and  BCL2L1
# looking for paths in the network with length:  3  for node  JUN  and  BCL2L1
# looking for paths in the network with length:  4  for node  JUN  and  BCL2L1
# Found a path!
# [['JUN', 'CREB1', 'MYC', 'BCL2L11', 'BCL2L1'], ['JUN', 'CREB1', 'MYC', 'CDKN2A', 'BCL2L1'], ['JUN', 'CREB1', 'CREBBP', 'STAT3', 'BCL2L1'], ['JUN', 'CTNNB1', 'FOXO3', 'BCL2L11', 'BCL2L1'], ['JUN', 'CTNNB1', 'CREBBP', 'STAT3', 'BCL2L1'], ['JUN', 'CTNNB1', 'FOXO1', 'STAT3', 'BCL2L1'], ['JUN', 'PPM1D', 'TP53', 'BID', 'BCL2L1'], ['JUN', 'PPM1D', 'MAPK14', 'BCL2L11', 'BCL2L1'], ['JUN', 'PPM1D', 'MAPK14', 'STAT3', 'BCL2L1'], ['JUN', 'PPM1D', 'RPS6KA3', 'BAD', 'BCL2L1'], ['JUN', 'SMAD3', 'FOXO1', 'STAT3', 'BCL2L1']]
# looking for paths in the network with length:  0  for node  JUN  and  BCL2L11
# looking for paths in the network with length:  1  for node  JUN  and  BCL2L11
# looking for paths in the network with length:  2  for node  JUN  and  BCL2L11
# looking for paths in the network with length:  3  for node  JUN  and  BCL2L11
# Found a path!
# [['JUN', 'CREB1', 'MYC', 'BCL2L11'], ['JUN', 'CTNNB1', 'FOXO3', 'BCL2L11'], ['JUN', 'PPM1D', 'MAPK14', 'BCL2L11']]
# looking for paths in the network with length:  0  for node  JUN  and  BID
# looking for paths in the network with length:  1  for node  JUN  and  BID
# looking for paths in the network with length:  2  for node  JUN  and  BID
# looking for paths in the network with length:  3  for node  JUN  and  BID
# Found a path!
# [['JUN', 'PPM1D', 'TP53', 'BID']]
# looking for paths in the network with length:  0  for node  JUN  and  BIRC5
# looking for paths in the network with length:  1  for node  JUN  and  BIRC5
# looking for paths in the network with length:  2  for node  JUN  and  BIRC5
# looking for paths in the network with length:  3  for node  JUN  and  BIRC5
# Found a path!
# [['JUN', 'PPM1D', 'TP53', 'BIRC5']]
# looking for paths in the network with length:  0  for node  JUN  and  CASP2
# looking for paths in the network with length:  1  for node  JUN  and  CASP2
# looking for paths in the network with length:  2  for node  JUN  and  CASP2
# looking for paths in the network with length:  3  for node  JUN  and  CASP2
# looking for paths in the network with length:  4  for node  JUN  and  CASP2
# Found a path!
# [['JUN', 'PPM1D', 'MAPK14', 'CASP3', 'CASP2']]
# looking for paths in the network with length:  0  for node  JUN  and  CASP3
# looking for paths in the network with length:  1  for node  JUN  and  CASP3
# looking for paths in the network with length:  2  for node  JUN  and  CASP3
# looking for paths in the network with length:  3  for node  JUN  and  CASP3
# Found a path!
# [['JUN', 'PPM1D', 'MAPK14', 'CASP3'], ['JUN', 'SMAD3', 'AKT1', 'CASP3'], ['JUN', 'GSK3A', 'AKT1', 'CASP3'], ['JUN', 'CREBBP', 'CTNNB1', 'CASP3'], ['JUN', 'GSK3B', 'AKT1', 'CASP3']]
# looking for paths in the network with length:  0  for node  JUN  and  CASP9
# looking for paths in the network with length:  1  for node  JUN  and  CASP9
# looking for paths in the network with length:  2  for node  JUN  and  CASP9
# looking for paths in the network with length:  3  for node  JUN  and  CASP9
# looking for paths in the network with length:  4  for node  JUN  and  CASP9
# Found a path!
# [['JUN', 'PPM1D', 'TP53', 'APAF1', 'CASP9'], ['JUN', 'PPM1D', 'TP53', 'BIRC5', 'CASP9'], ['JUN', 'PPM1D', 'MAPK14', 'CASP3', 'CASP9'], ['JUN', 'PPM1D', 'MAPK14', 'MAPK1', 'CASP9'], ['JUN', 'PPM1D', 'MAPK14', 'MAPK3', 'CASP9'], ['JUN', 'PPM1D', 'MAPK14', 'PRKACA', 'CASP9'], ['JUN', 'SMAD3', 'AKT1', 'CASP3', 'CASP9'], ['JUN', 'GSK3A', 'AKT1', 'CASP3', 'CASP9'], ['JUN', 'CREBBP', 'CTNNB1', 'CASP3', 'CASP9'], ['JUN', 'GSK3B', 'AKT1', 'CASP3', 'CASP9']]
# looking for paths in the network with length:  0  for node  JUN  and  RASGRF1
# looking for paths in the network with length:  1  for node  JUN  and  RASGRF1
# looking for paths in the network with length:  2  for node  JUN  and  RASGRF1
# looking for paths in the network with length:  3  for node  JUN  and  RASGRF1
# looking for paths in the network with length:  4  for node  JUN  and  RASGRF1
# Found a path!
# [['JUN', 'PPM1D', 'MAPK14', 'PRKACA', 'RASGRF1']]
# looking for paths in the network with length:  0  for node  JUN  and  CDKN1A
# looking for paths in the network with length:  1  for node  JUN  and  CDKN1A
# looking for paths in the network with length:  2  for node  JUN  and  CDKN1A
# looking for paths in the network with length:  3  for node  JUN  and  CDKN1A
# Found a path!
# [['JUN', 'CREB1', 'CDK6', 'CDKN1A'], ['JUN', 'CREB1', 'MYC', 'CDKN1A'], ['JUN', 'CTNNB1', 'FOXO3', 'CDKN1A'], ['JUN', 'CTNNB1', 'FOXO1', 'CDKN1A'], ['JUN', 'PPM1D', 'TP53', 'CDKN1A'], ['JUN', 'PPM1D', 'MAPK14', 'CDKN1A'], ['JUN', 'SMAD3', 'FOXO1', 'CDKN1A'], ['JUN', 'SMAD3', 'CDK4', 'CDKN1A'], ['JUN', 'SMAD3', 'CDK2', 'CDKN1A']]
# looking for paths in the network with length:  0  for node  JUN  and  CDKN1B
# looking for paths in the network with length:  1  for node  JUN  and  CDKN1B
# looking for paths in the network with length:  2  for node  JUN  and  CDKN1B
# looking for paths in the network with length:  3  for node  JUN  and  CDKN1B
# Found a path!
# [['JUN', 'CREB1', 'CDK6', 'CDKN1B'], ['JUN', 'CTNNB1', 'FOXO3', 'CDKN1B'], ['JUN', 'CTNNB1', 'FOXO1', 'CDKN1B'], ['JUN', 'SMAD3', 'FOXO1', 'CDKN1B'], ['JUN', 'SMAD3', 'CDK2', 'CDKN1B']]
# looking for paths in the network with length:  0  for node  JUN  and  CDKN2A
# looking for paths in the network with length:  1  for node  JUN  and  CDKN2A
# looking for paths in the network with length:  2  for node  JUN  and  CDKN2A
# looking for paths in the network with length:  3  for node  JUN  and  CDKN2A
# Found a path!
# [['JUN', 'CREB1', 'MYC', 'CDKN2A'], ['JUN', 'SMAD3', 'CDK4', 'CDKN2A'], ['JUN', 'SMAD3', 'MYC', 'CDKN2A'], ['JUN', 'SMAD3', 'CDK2', 'CDKN2A']]
# looking for paths in the network with length:  0  for node  JUN  and  CREB1
# looking for paths in the network with length:  1  for node  JUN  and  CREB1
# Found a path!
# [['JUN', 'CREB1']]
# looking for paths in the network with length:  0  for node  JUN  and  CTNNB1
# looking for paths in the network with length:  1  for node  JUN  and  CTNNB1
# Found a path!
# [['JUN', 'CTNNB1']]
# looking for paths in the network with length:  0  for node  JUN  and  CYCS
# looking for paths in the network with length:  1  for node  JUN  and  CYCS
# ...
# looking for paths in the network with length:  0  for node  DUSP1  and  BRAF
# looking for paths in the network with length:  1  for node  DUSP1  and  BRAF
# looking for paths in the network with length:  2  for node  DUSP1  and  BRAF
# Found a path!
# [['DUSP1', 'MAPK1', 'BRAF'], ['DUSP1', 'MAPK3', 'BRAF'], ['DUSP1', 'MAPK1', 'BRAF'], ['DUSP1', 'MAPK3', 'BRAF']]
# looking for paths in the network with length:  0  for node  DUSP1  and  KRAS
# looking for paths in the network with length:  1  for node  DUSP1  and  KRAS
# looking for paths in the network with length:  2  for node  DUSP1  and  KRAS
# looking for paths in the network with length:  3  for node  DUSP1  and  KRAS
# Found a path!
# [['DUSP1', 'MAPK8', 'SRC', 'KRAS'], ['DUSP1', 'MAPK1', 'PRKCA', 'KRAS'], ['DUSP1', 'MAPK1', 'BRAF', 'KRAS'], ['DUSP1', 'MAPK1', 'MAP3K1', 'KRAS'], ['DUSP1', 'MAPK3', 'BRAF', 'KRAS'], ['DUSP1', 'MAPK3', 'MAP3K1', 'KRAS']]
# looking for paths in the network with length:  0  for node  DUSP1  and  EGFR
# looking for paths in the network with length:  1  for node  DUSP1  and  EGFR
# looking for paths in the network with length:  2  for node  DUSP1  and  EGFR
# Found a path!
# [['DUSP1', 'MAPK1', 'EGFR'], ['DUSP1', 'MAPK14', 'EGFR'], ['DUSP1', 'MAPK3', 'EGFR']]
# looking for paths in the network with length:  0  for node  DUSP1  and  FOXO1
# looking for paths in the network with length:  1  for node  DUSP1  and  FOXO1
# looking for paths in the network with length:  2  for node  DUSP1  and  FOXO1
# looking for paths in the network with length:  3  for node  DUSP1  and  FOXO1
# Found a path!
# [['DUSP1', 'MAPK8', 'ESR1', 'FOXO1'], ['DUSP1', 'MAPK8', 'SMAD3', 'FOXO1'], ['DUSP1', 'MAPK8', 'AKT1', 'FOXO1'], ['DUSP1', 'MAPK1', 'ESR1', 'FOXO1'], ['DUSP1', 'MAPK1', 'DUSP6', 'FOXO1'], ['DUSP1', 'MAPK1', 'SMAD3', 'FOXO1'], ['DUSP1', 'MAPK1', 'CDK2', 'FOXO1'], ['DUSP1', 'MAPK1', 'AR', 'FOXO1'], ['DUSP1', 'MAPK1', 'CDK1', 'FOXO1'], ['DUSP1', 'MAPK9', 'CTNNB1', 'FOXO1'], ['DUSP1', 'MAPK14', 'ESR1', 'FOXO1'], ['DUSP1', 'MAPK14', 'SMAD3', 'FOXO1'], ['DUSP1', 'MAPK14', 'AR', 'FOXO1'], ['DUSP1', 'MAPK3', 'ESR1', 'FOXO1'], ['DUSP1', 'MAPK3', 'DUSP6', 'FOXO1'], ['DUSP1', 'MAPK3', 'SMAD3', 'FOXO1']]
# looking for paths in the network with length:  0  for node  DUSP1  and  PIK3CA
# looking for paths in the network with length:  1  for node  DUSP1  and  PIK3CA
# looking for paths in the network with length:  2  for node  DUSP1  and  PIK3CA
# looking for paths in the network with length:  3  for node  DUSP1  and  PIK3CA
# Found a path!
# [['DUSP1', 'MAPK8', 'IRS1', 'PIK3CA'], ['DUSP1', 'MAPK8', 'SRC', 'PIK3CA'], ['DUSP1', 'MAPK8', 'RAC1', 'PIK3CA'], ['DUSP1', 'MAPK1', 'IRS1', 'PIK3CA'], ['DUSP1', 'MAPK1', 'FOXO3', 'PIK3CA'], ['DUSP1', 'MAPK9', 'IRS1', 'PIK3CA'], ['DUSP1', 'MAPK14', 'FOXO3', 'PIK3CA'], ['DUSP1', 'MAPK3', 'IRS1', 'PIK3CA'], ['DUSP1', 'MAPK3', 'FOXO3', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  DUSP1  and  RICTOR
# looking for paths in the network with length:  1  for node  DUSP1  and  RICTOR
# looking for paths in the network with length:  2  for node  DUSP1  and  RICTOR
# looking for paths in the network with length:  3  for node  DUSP1  and  RICTOR
# Found a path!
# [['DUSP1', 'MAPK8', 'RPS6KB1', 'RICTOR'], ['DUSP1', 'MAPK1', 'RPS6KB1', 'RICTOR'], ['DUSP1', 'MAPK3', 'RPS6KB1', 'RICTOR'], ['DUSP1', 'EP300', 'AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  DUSP1  and  MAP2K4
# looking for paths in the network with length:  1  for node  DUSP1  and  MAP2K4
# looking for paths in the network with length:  2  for node  DUSP1  and  MAP2K4
# Found a path!
# [['DUSP1', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  CCNA1  and  BRAF
# looking for paths in the network with length:  1  for node  CCNA1  and  BRAF
# looking for paths in the network with length:  2  for node  CCNA1  and  BRAF
# looking for paths in the network with length:  3  for node  CCNA1  and  BRAF
# looking for paths in the network with length:  4  for node  CCNA1  and  BRAF
# Found a path!
# [['CCNA1', 'E2F1', 'CASP3', 'AKT1', 'BRAF'], ['CCNA1', 'ELAVL1', 'HDAC6', 'MAPK3', 'BRAF']]
# looking for paths in the network with length:  0  for node  CCNA1  and  KRAS
# looking for paths in the network with length:  1  for node  CCNA1  and  KRAS
# looking for paths in the network with length:  2  for node  CCNA1  and  KRAS
# looking for paths in the network with length:  3  for node  CCNA1  and  KRAS
# looking for paths in the network with length:  4  for node  CCNA1  and  KRAS
# i_search =  4
# Looking for paths with length:  0  for node  CCNA1  and  KRAS
# i_search =  4
# Looking for paths with length:  1  for node  CCNA1  and  KRAS
# i_search =  4
# Looking for paths with length:  2  for node  CCNA1  and  KRAS
# i_search =  4
# Looking for paths with length:  3  for node  CCNA1  and  KRAS
# i_search =  4
# Looking for paths with length:  4  for node  CCNA1  and  KRAS
# looking for paths in the network with length:  0  for node  CCNA1  and  EGFR
# looking for paths in the network with length:  1  for node  CCNA1  and  EGFR
# looking for paths in the network with length:  2  for node  CCNA1  and  EGFR
# looking for paths in the network with length:  3  for node  CCNA1  and  EGFR
# Found a path!
# [['CCNA1', 'E2F1', 'TP53', 'EGFR'], ['CCNA1', 'E2F1', 'CDK1', 'EGFR'], ['CCNA1', 'ELAVL1', 'HDAC6', 'EGFR']]
# looking for paths in the network with length:  0  for node  CCNA1  and  FOXO1
# looking for paths in the network with length:  1  for node  CCNA1  and  FOXO1
# looking for paths in the network with length:  2  for node  CCNA1  and  FOXO1
# looking for paths in the network with length:  3  for node  CCNA1  and  FOXO1
# Found a path!
# [['CCNA1', 'E2F1', 'CDK1', 'FOXO1']]
# looking for paths in the network with length:  0  for node  CCNA1  and  PIK3CA
# looking for paths in the network with length:  1  for node  CCNA1  and  PIK3CA
# looking for paths in the network with length:  2  for node  CCNA1  and  PIK3CA
# looking for paths in the network with length:  3  for node  CCNA1  and  PIK3CA
# looking for paths in the network with length:  4  for node  CCNA1  and  PIK3CA
# Found a path!
# [['CCNA1', 'E2F1', 'HDAC1', 'FOXO3', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  CCNA1  and  RICTOR
# looking for paths in the network with length:  1  for node  CCNA1  and  RICTOR
# looking for paths in the network with length:  2  for node  CCNA1  and  RICTOR
# looking for paths in the network with length:  3  for node  CCNA1  and  RICTOR
# looking for paths in the network with length:  4  for node  CCNA1  and  RICTOR
# Found a path!
# [['CCNA1', 'E2F1', 'CDK1', 'RPS6KB1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  CCNA1  and  MAP2K4
# looking for paths in the network with length:  1  for node  CCNA1  and  MAP2K4
# looking for paths in the network with length:  2  for node  CCNA1  and  MAP2K4
# looking for paths in the network with length:  3  for node  CCNA1  and  MAP2K4
# Found a path!
# [['CCNA1', 'E2F1', 'MAP3K5', 'MAP2K4'], ['CCNA1', 'ELAVL1', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  BRAF  and  KRAS
# looking for paths in the network with length:  1  for node  BRAF  and  KRAS
# Found a path!
# [['BRAF', 'KRAS']]
# looking for paths in the network with length:  0  for node  BRAF  and  EGFR
# looking for paths in the network with length:  1  for node  BRAF  and  EGFR
# looking for paths in the network with length:  2  for node  BRAF  and  EGFR
# Found a path!
# [['BRAF', 'MAPK1', 'EGFR'], ['BRAF', 'MAPK3', 'EGFR']]
# looking for paths in the network with length:  0  for node  BRAF  and  FOXO1
# looking for paths in the network with length:  1  for node  BRAF  and  FOXO1
# looking for paths in the network with length:  2  for node  BRAF  and  FOXO1
# looking for paths in the network with length:  3  for node  BRAF  and  FOXO1
# Found a path!
# [['BRAF', 'MAPK1', 'ESR1', 'FOXO1'], ['BRAF', 'MAPK1', 'DUSP6', 'FOXO1'], ['BRAF', 'MAPK1', 'SMAD3', 'FOXO1'], ['BRAF', 'MAPK1', 'CDK2', 'FOXO1'], ['BRAF', 'MAPK1', 'AR', 'FOXO1'], ['BRAF', 'MAPK1', 'CDK1', 'FOXO1'], ['BRAF', 'MAPK3', 'ESR1', 'FOXO1'], ['BRAF', 'MAPK3', 'DUSP6', 'FOXO1'], ['BRAF', 'MAPK3', 'SMAD3', 'FOXO1']]
# looking for paths in the network with length:  0  for node  BRAF  and  PIK3CA
# looking for paths in the network with length:  1  for node  BRAF  and  PIK3CA
# looking for paths in the network with length:  2  for node  BRAF  and  PIK3CA
# looking for paths in the network with length:  3  for node  BRAF  and  PIK3CA
# Found a path!
# [['BRAF', 'MAPK1', 'IRS1', 'PIK3CA'], ['BRAF', 'MAPK1', 'FOXO3', 'PIK3CA'], ['BRAF', 'MAP2K1', 'IRS1', 'PIK3CA'], ['BRAF', 'MAPK3', 'IRS1', 'PIK3CA'], ['BRAF', 'MAPK3', 'FOXO3', 'PIK3CA'], ['BRAF', 'PRKACA', 'PDPK1', 'PIK3CA'], ['BRAF', 'PRKACA', 'SRC', 'PIK3CA'], ['BRAF', 'AKT1', 'PDPK1', 'PIK3CA'], ['BRAF', 'AKT1', 'IRS1', 'PIK3CA'], ['BRAF', 'AKT1', 'RAC1', 'PIK3CA'], ['BRAF', 'AKT1', 'SRC', 'PIK3CA'], ['BRAF', 'KRAS', 'SRC', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  BRAF  and  RICTOR
# looking for paths in the network with length:  1  for node  BRAF  and  RICTOR
# looking for paths in the network with length:  2  for node  BRAF  and  RICTOR
# Found a path!
# [['BRAF', 'AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  BRAF  and  MAP2K4
# looking for paths in the network with length:  1  for node  BRAF  and  MAP2K4
# looking for paths in the network with length:  2  for node  BRAF  and  MAP2K4
# looking for paths in the network with length:  3  for node  BRAF  and  MAP2K4
# Found a path!
# [['BRAF', 'MAPK1', 'MAP3K5', 'MAP2K4'], ['BRAF', 'PRKACA', 'MAPK14', 'MAP2K4'], ['BRAF', 'MAPK1', 'MAPK14', 'MAP2K4'], ['BRAF', 'AKT1', 'MAPK8', 'MAP2K4'], ['BRAF', 'MAPK3', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  KRAS  and  EGFR
# looking for paths in the network with length:  1  for node  KRAS  and  EGFR
# looking for paths in the network with length:  2  for node  KRAS  and  EGFR
# looking for paths in the network with length:  3  for node  KRAS  and  EGFR
# Found a path!
# [['KRAS', 'PIK3CA', 'SRC', 'EGFR'], ['KRAS', 'MAP3K1', 'MAPK1', 'EGFR'], ['KRAS', 'MAP3K1', 'MAPK3', 'EGFR'], ['KRAS', 'BRAF', 'MAPK1', 'EGFR'], ['KRAS', 'BRAF', 'MAPK3', 'EGFR'], ['KRAS', 'PRKCA', 'PPP2CA', 'EGFR'], ['KRAS', 'PRKCA', 'STAT3', 'EGFR'], ['KRAS', 'SRC', 'PPP2CA', 'EGFR'], ['KRAS', 'SRC', 'STAT3', 'EGFR']]
# looking for paths in the network with length:  0  for node  KRAS  and  FOXO1
# looking for paths in the network with length:  1  for node  KRAS  and  FOXO1
# looking for paths in the network with length:  2  for node  KRAS  and  FOXO1
# looking for paths in the network with length:  3  for node  KRAS  and  FOXO1
# Found a path!
# [['KRAS', 'COMPLEX:P27986_P42336', 'AKT1', 'FOXO1'], ['KRAS', 'PRKCA', 'STAT3', 'FOXO1'], ['KRAS', 'SRC', 'STAT3', 'FOXO1']]
# looking for paths in the network with length:  0  for node  KRAS  and  PIK3CA
# looking for paths in the network with length:  1  for node  KRAS  and  PIK3CA
# Found a path!
# [['KRAS', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  KRAS  and  RICTOR
# looking for paths in the network with length:  1  for node  KRAS  and  RICTOR
# looking for paths in the network with length:  2  for node  KRAS  and  RICTOR
# looking for paths in the network with length:  3  for node  KRAS  and  RICTOR
# Found a path!
# [['KRAS', 'PIK3CA', 'RPS6KB1', 'RICTOR'], ['KRAS', 'DAB2IP', 'AKT1', 'RICTOR'], ['KRAS', 'SRC', 'AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  KRAS  and  MAP2K4
# looking for paths in the network with length:  1  for node  KRAS  and  MAP2K4
# looking for paths in the network with length:  2  for node  KRAS  and  MAP2K4
# Found a path!
# [['KRAS', 'MAP3K1', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  EGFR  and  FOXO1
# looking for paths in the network with length:  1  for node  EGFR  and  FOXO1
# looking for paths in the network with length:  2  for node  EGFR  and  FOXO1
# Found a path!
# [['EGFR', 'CTNNB1', 'FOXO1'], ['EGFR', 'ESR1', 'FOXO1'], ['EGFR', 'AR', 'FOXO1']]
# looking for paths in the network with length:  0  for node  EGFR  and  PIK3CA
# looking for paths in the network with length:  1  for node  EGFR  and  PIK3CA
# looking for paths in the network with length:  2  for node  EGFR  and  PIK3CA
# Found a path!
# [['EGFR', 'SRC', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  EGFR  and  RICTOR
# looking for paths in the network with length:  1  for node  EGFR  and  RICTOR
# looking for paths in the network with length:  2  for node  EGFR  and  RICTOR
# looking for paths in the network with length:  3  for node  EGFR  and  RICTOR
# Found a path!
# [['EGFR', 'PPP2CA', 'RPS6KB1', 'RICTOR'], ['EGFR', 'SRC', 'AKT1', 'RICTOR'], ['EGFR', 'AR', 'AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  EGFR  and  MAP2K4
# looking for paths in the network with length:  1  for node  EGFR  and  MAP2K4
# looking for paths in the network with length:  2  for node  EGFR  and  MAP2K4
# Found a path!
# [['EGFR', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  FOXO1  and  PIK3CA
# looking for paths in the network with length:  1  for node  FOXO1  and  PIK3CA
# looking for paths in the network with length:  2  for node  FOXO1  and  PIK3CA
# looking for paths in the network with length:  3  for node  FOXO1  and  PIK3CA
# Found a path!
# [['FOXO1', 'STAT3', 'SRC', 'PIK3CA'], ['FOXO1', 'AR', 'FOXO3', 'PIK3CA'], ['FOXO1', 'CTNNB1', 'SRC', 'PIK3CA'], ['FOXO1', 'ESR1', 'SRC', 'PIK3CA'], ['FOXO1', 'ESR1', 'RPS6KB1', 'PIK3CA'], ['FOXO1', 'AKT1', 'PDPK1', 'PIK3CA'], ['FOXO1', 'AKT1', 'IRS1', 'PIK3CA'], ['FOXO1', 'AKT1', 'RAC1', 'PIK3CA'], ['FOXO1', 'AKT1', 'SRC', 'PIK3CA'], ['FOXO1', 'AR', 'SRC', 'PIK3CA']]
# looking for paths in the network with length:  0  for node  FOXO1  and  RICTOR
# looking for paths in the network with length:  1  for node  FOXO1  and  RICTOR
# looking for paths in the network with length:  2  for node  FOXO1  and  RICTOR
# Found a path!
# [['FOXO1', 'AKT1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  FOXO1  and  MAP2K4
# looking for paths in the network with length:  1  for node  FOXO1  and  MAP2K4
# looking for paths in the network with length:  2  for node  FOXO1  and  MAP2K4
# looking for paths in the network with length:  3  for node  FOXO1  and  MAP2K4
# Found a path!
# [['FOXO1', 'CTNNB1', 'MAPK9', 'MAP2K4'], ['FOXO1', 'SMAD3', 'MAPK8', 'MAP2K4'], ['FOXO1', 'SMAD3', 'MAPK14', 'MAP2K4'], ['FOXO1', 'ESR1', 'MAPK8', 'MAP2K4'], ['FOXO1', 'ESR1', 'MAPK14', 'MAP2K4'], ['FOXO1', 'AKT1', 'MAPK8', 'MAP2K4'], ['FOXO1', 'AR', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  PIK3CA  and  RICTOR
# looking for paths in the network with length:  1  for node  PIK3CA  and  RICTOR
# looking for paths in the network with length:  2  for node  PIK3CA  and  RICTOR
# Found a path!
# [['PIK3CA', 'RPS6KB1', 'RICTOR']]
# looking for paths in the network with length:  0  for node  PIK3CA  and  MAP2K4
# looking for paths in the network with length:  1  for node  PIK3CA  and  MAP2K4
# looking for paths in the network with length:  2  for node  PIK3CA  and  MAP2K4
# looking for paths in the network with length:  3  for node  PIK3CA  and  MAP2K4
# Found a path!
# [['PIK3CA', 'PDPK1', 'AKT1', 'MAP2K4'], ['PIK3CA', 'RAC1', 'MAP3K1', 'MAP2K4'], ['PIK3CA', 'RAC1', 'AKT1', 'MAP2K4'], ['PIK3CA', 'SRC', 'AKT1', 'MAP2K4'], ['PIK3CA', 'IRS1', 'AKT1', 'MAP2K4'], ['PIK3CA', 'RAC1', 'MAPK8', 'MAP2K4'], ['PIK3CA', 'SRC', 'MAPK8', 'MAP2K4'], ['PIK3CA', 'IRS1', 'MAPK8', 'MAP2K4'], ['PIK3CA', 'IRS1', 'MAPK9', 'MAP2K4'], ['PIK3CA', 'FOXO3', 'MAPK14', 'MAP2K4']]
# looking for paths in the network with length:  0  for node  RICTOR  and  MAP2K4
# looking for paths in the network with length:  1  for node  RICTOR  and  MAP2K4
# looking for paths in the network with length:  2  for node  RICTOR  and  MAP2K4
# Found a path!
# [['RICTOR', 'AKT1', 'MAP2K4']]
# CPU times: user 1h 36min 33s, sys: 10.8 s, total: 1h 36min 44s
# Wall time: 1h 36min 42s

# %%
visualizer1 = NetworkVisualizer(new_net1, color_by='effect')
visualizer1.render(output_file='network1')

# %%
list(set(new_net1.nodes["Genesymbol"]))
# Out:
# ['CDH2', 'RRAS', 'DAB1', 'SRC', 'PTK2B', 'PTK2', 'CHUK', 'CTNNB1', 'NOTCH1']

# %%
new_net1.edges
# Out:
#                                                   source  \
# 15367  COMPLEX:O43741_P54619_P54646_Q13131_Q9UGI9_Q9U...
# 4093                                                ULK1
# 55038         COMPLEX:P42345_Q8N122_Q8TB45_Q96B36_Q9BVC4
# 20331                                               AKT1
# 15021  COMPLEX:O43741_P54619_P54646_Q13131_Q9UGI9_Q9U...
# 53211                       COMPLEX:O75143_O75385_Q8TDY2
# 28187  COMPLEX:O43741_P54619_P54646_Q13131_Q9UGI9_Q9U...
# 15022                       COMPLEX:O75143_O75385_Q8TDY2
# 53212         COMPLEX:P42345_Q8N122_Q8TB45_Q96B36_Q9BVC4
#
#                                                   target                Type  \
# 15367                                              FOXO3  post_translational
# 4093   COMPLEX:O43741_P54619_P54646_Q13131_Q9UGI9_Q9U...  post_translational
# 55038                                               ULK1  post_translational
# 20331         COMPLEX:P42345_Q8N122_Q8TB45_Q96B36_Q9BVC4  post_translational
# 15021                       COMPLEX:O75143_O75385_Q8TDY2  post_translational
# 53211         COMPLEX:P42345_Q8N122_Q8TB45_Q96B36_Q9BVC4  post_translational
# 28187         COMPLEX:P42345_Q8N122_Q8TB45_Q96B36_Q9BVC4  post_translational
# 15022  COMPLEX:O43741_P54619_P54646_Q13131_Q9UGI9_Q9U...  post_translational
# 53212                       COMPLEX:O75143_O75385_Q8TDY2  post_translational
#
#             Effect                                         References
# 15367  stimulation    SIGNOR:17711846;SIGNOR:17900900;SIGNOR:22848740
# 4093    inhibition                                    SIGNOR:21460634
# 55038   inhibition                                    SIGNOR:19690328
# 20331  stimulation    SIGNOR:15829723;SIGNOR:17130464;SIGNOR:20138985
# 15021  stimulation                                    SIGNOR:23863160
# 53211   inhibition                                    SIGNOR:23863160
# 28187   inhibition  SIGNOR:18439900;SIGNOR:20083114;SIGNOR:2146063...
# 15022   inhibition                                    SIGNOR:21460634
# 53212   inhibition                                    SIGNOR:23863160

# %% [markdown]
# ### If the all_interaction database of omnipath is not sufficient, we can change it or extend it. To do it, we can use the Resources object:

# %%
interactions = op.interactions.AllInteractions.get() #first we get the interactions from omnipath

# %%
interactions[interactions.sources.isin(["SIGNOR"])]
# Out:
#          source                 target  is_directed  is_stimulation  \
# 986      P23458  COMPLEX:P15260_P38484         True            True
# 993      O60674  COMPLEX:P15260_P38484         True            True
# 1006     P53355                 P46821         True            True
# 2639     P14618  COMPLEX:P27540_Q16665         True            True
# 3048     A8MT69                 Q8IYD8         True            True
# ...         ...                    ...          ...             ...
# 273958   443872                 P08235         True           False
# 273959     5073                 P28223         True           False
# 273960     5736                 P08908         True           False
# 273962     3396                 P28223         True           False
# 273963  9869779                 P07333         True           False
#
#         is_inhibition  consensus_direction  consensus_stimulation  \
# 986             False                False                  False
# 993             False                False                  False
# 1006            False                False                  False
# 2639            False                False                  False
# 3048            False                False                  False
# ...               ...                  ...                    ...
# 273958           True                 True                  False
# 273959           True                 True                  False
# 273960           True                 True                  False
# 273962           True                 True                  False
# 273963           True                 True                  False
#
#         consensus_inhibition  curation_effort       references sources  \
# 986                    False                1  SIGNOR:19041276  SIGNOR
# 993                    False                1  SIGNOR:23898330  SIGNOR
# 1006                   False                1  SIGNOR:18806760  SIGNOR
# 2639                   False                1  SIGNOR:21620138  SIGNOR
# 3048                   False                1  SIGNOR:20347429  SIGNOR
# ...                      ...              ...              ...     ...
# 273958                  True                1  SIGNOR:18038968  SIGNOR
# 273959                  True                1   SIGNOR:8935801  SIGNOR
# 273960                  True                1   SIGNOR:8935801  SIGNOR
# 273962                  True                1   SIGNOR:8935801  SIGNOR
# 273963                  True                1  SIGNOR:22037378  SIGNOR
#
#                           type  n_sources  n_primary_sources n_references  \
# 986         post_translational          1                  1            1
# 993         post_translational          1                  1            1
# 1006        post_translational          1                  1            1
# 2639        post_translational          1                  1            1
# 3048        post_translational          1                  1            1
# ...                        ...        ...                ...          ...
# 273958  small_molecule_protein          1                  1            1
# 273959  small_molecule_protein          1                  1            1
# 273960  small_molecule_protein          1                  1            1
# 273962  small_molecule_protein          1                  1            1
# 273963  small_molecule_protein          1                  1            1
#
#        references_stripped
# 986               19041276
# 993               23898330
# 1006              18806760
# 2639              21620138
# 3048              20347429
# ...                    ...
# 273958            18038968
# 273959             8935801
# 273960             8935801
# 273962             8935801
# 273963            22037378
#
# [54680 rows x 16 columns]

# %% [markdown]
# ### Then, we can add allInteractions in the Resources object

# %%
resources = Resources()
resources.add_database(interactions)

# %%
resources.interactions
# Out:
#         source  target  is_directed  is_stimulation  is_inhibition  \
# 0       P0DP23  P48995         True           False           True
# 1       P0DP25  P48995         True           False           True
# 2       P0DP24  P48995         True           False           True
# 3       Q03135  P48995         True            True          False
# 4       P14416  P48995         True            True          False
# ...        ...     ...          ...             ...            ...
# 276174  439260  P35348         True           False          False
# 276175    5202  Q13639         True           False          False
# 276176    6305  Q6DWJ6         True           False          False
# 276177  643961  Q9GZU1         True           False          False
# 276178  448457  Q13258         True           False          False
#
#         consensus_direction  consensus_stimulation  consensus_inhibition  \
# 0                      True                  False                  True
# 1                      True                  False                  True
# 2                      True                  False                  True
# 3                      True                   True                 False
# 4                      True                   True                 False
# ...                     ...                    ...                   ...
# 276174                False                  False                 False
# 276175                False                  False                 False
# 276176                False                  False                 False
# 276177                False                  False                 False
# 276178                False                  False                 False
#
#         curation_effort                                         references  \
# 0                     3          TRIP:11290752;TRIP:11983166;TRIP:12601176
# 1                     3          TRIP:11290752;TRIP:11983166;TRIP:12601176
# 2                     3          TRIP:11290752;TRIP:11983166;TRIP:12601176
# 3                    13  DIP:19897728;HPRD:12732636;IntAct:19897728;Lit...
# 4                     1                                      TRIP:18261457
# ...                 ...                                                ...
# 276174                3  Cellinker:10433504;Cellinker:7651358;Cellinker...
# 276175               10  Cellinker:10646498;Cellinker:10683202;Cellinke...
# 276176                1                                 Cellinker:26349500
# 276177                1                                 Cellinker:20802798
# 276178                4  Cellinker:10448933;Cellinker:16604093;Cellinke...
#
#                                  sources                    type  n_sources  \
# 0                                   TRIP      post_translational          1
# 1                                   TRIP      post_translational          1
# 2                                   TRIP      post_translational          1
# 3         DIP;HPRD;IntAct;Lit-BM-17;TRIP      post_translational          5
# 4                                   TRIP      post_translational          1
# ...                                  ...                     ...        ...
# 276174  Cellinker;Guide2Pharma_Cellinker  small_molecule_protein          2
# 276175  Cellinker;Guide2Pharma_Cellinker  small_molecule_protein          2
# 276176  Cellinker;Guide2Pharma_Cellinker  small_molecule_protein          2
# 276177  Cellinker;Guide2Pharma_Cellinker  small_molecule_protein          2
# 276178  Cellinker;Guide2Pharma_Cellinker  small_molecule_protein          2
#
#         n_primary_sources n_references  \
# 0                       1            3
# 1                       1            3
# 2                       1            3
# 3                       5            8
# 4                       1            1
# ...                   ...          ...
# 276174                  1            3
# 276175                  1           10
# 276176                  1            1
# 276177                  1            1
# 276178                  1            4
#
#                                       references_stripped
# 0                              11290752;11983166;12601176
# 1                              11290752;11983166;12601176
# 2                              11290752;11983166;12601176
# 3       10980191;12732636;14551243;16822931;18430726;1...
# 4                                                18261457
# ...                                                   ...
# 276174                           10433504;7651358;8564227
# 276175  10646498;10683202;10821780;11030734;11218067;1...
# 276176                                           26349500
# 276177                                           20802798
# 276178                  10448933;16604093;7642548;9579725
#
# [276179 rows x 16 columns]

# %% [markdown]
# ### Now we can explore another database we are interested in, for example, the ligand receptor one

# %%
extra = op.interactions.LigRecExtra.get()

# %% [markdown]
# ### And then we add it to the Resources object

# %%
resources.add_database(extra, reset_index=True)

# %% [markdown]
# ### Now we create the network with a similar list of genes but specifying the Resource object

# %%
genes = ["SRC", "NOTCH1", "PTK2", "CDH1", "CDH2", "VIM", "MAP4K4", "PTK2B", "COL1A1"]

# %%
# %%time
new_net1 = Network(genes, resources=resources)
# Out:
# CPU times: user 27.1 ms, sys: 0 ns, total: 27.1 ms
# Wall time: 26.5 ms

# %%
# %%time
new_net1.connect_nodes(only_signed=True, consensus_only=True)
# Out:
# P12931 Q05397
# P12830 P12931
# P12931 P19022
# P12931 Q14289
# P02452 P12931
# P46531 P19022
# P46531 P02452
# Q14289 Q05397
# CPU times: user 1.19 s, sys: 4.05 ms, total: 1.2 s
# Wall time: 1.2 s

# %%
# %%time
new_net1.complete_connection(mode="ALL", maxlen=3, k_mean="tight", only_signed=True,
                            consensus=True, connect_node_when_first_introduced=True)
# Out:
# looking for paths in the network with length:  0  for node  SRC  and  NOTCH1
# looking for paths in the network with length:  1  for node  SRC  and  NOTCH1
# looking for paths in the network with length:  2  for node  SRC  and  NOTCH1
# Found a path!
# [['SRC', 'COL1A1', 'NOTCH1'], ['SRC', 'CDH2', 'NOTCH1']]
# looking for paths in the network with length:  0  for node  SRC  and  PTK2
# looking for paths in the network with length:  1  for node  SRC  and  PTK2
# Found a path!
# [['SRC', 'PTK2']]
# looking for paths in the network with length:  0  for node  SRC  and  CDH1
# looking for paths in the network with length:  1  for node  SRC  and  CDH1
# Found a path!
# [['SRC', 'CDH1']]
# looking for paths in the network with length:  0  for node  SRC  and  CDH2
# looking for paths in the network with length:  1  for node  SRC  and  CDH2
# Found a path!
# [['SRC', 'CDH2']]
# looking for paths in the network with length:  0  for node  SRC  and  VIM
# looking for paths in the network with length:  1  for node  SRC  and  VIM
# looking for paths in the network with length:  2  for node  SRC  and  VIM
# looking for paths in the network with length:  3  for node  SRC  and  VIM
# i_search =  3
# Looking for paths with length:  0  for node  SRC  and  VIM
# i_search =  3
# Looking for paths with length:  1  for node  SRC  and  VIM
# i_search =  3
# Looking for paths with length:  2  for node  SRC  and  VIM
# [['SRC', 'COMPLEX:P05412_P53539', 'VIM'], ['SRC', 'COMPLEX:P19838_Q04206', 'VIM'], ['SRC', 'COMPLEX:P17535_P53539', 'VIM'], ['SRC', 'JDP2', 'VIM'], ['SRC', 'NFKB1', 'VIM'], ['SRC', 'TCF7L2', 'VIM'], ['SRC', 'RELB', 'VIM'], ['SRC', 'COMPLEX:P15408_P17275', 'VIM'], ['SRC', 'COMPLEX:P15407_P17535', 'VIM'], ['SRC', 'SP1', 'VIM'], ['SRC', 'COMPLEX:P01100_P17275', 'VIM'], ['SRC', 'COMPLEX:P19838_Q04864', 'VIM'], ['SRC', 'RELA', 'VIM'], ['SRC', 'COMPLEX:P19838_Q01201', 'VIM'], ['SRC', 'COMPLEX:P15407_P17275', 'VIM'], ['SRC', 'COMPLEX:P05412_P17275', 'VIM'], ['SRC', 'JUND', 'VIM'], ['SRC', 'SP3', 'VIM'], ['SRC', 'STAT5A', 'VIM'], ['SRC', 'COMPLEX:Q00653_Q01201', 'VIM'], ['SRC', 'COMPLEX:P17275_P53539', 'VIM'], ['SRC', 'COMPLEX:P19838_Q00653', 'VIM'], ['SRC', 'COMPLEX:P15408_P17535', 'VIM'], ['SRC', 'COMPLEX:Q00653_Q04206', 'VIM'], ['SRC', 'NFKB1',
# COMPLEX:P19838_Q00653 Q02447
# COMPLEX:P15408_P17535 Q02447
# COMPLEX:Q00653_Q04206 Q02447
# COMPLEX:P19838 Q02447
# COMPLEX:Q04864 Q02447
# COMPLEX:P05412_P17535 Q02447
# COMPLEX:P01100_P05412 Q02447
# COMPLEX:P17275 Q02447
# COMPLEX:P05412_P15407 Q02447
# COMPLEX:P05412 Q02447
# COMPLEX:P01100_P17535 Q02447
# COMPLEX:Q04206_Q04864 Q02447
# COMPLEX:Q01201_Q04864 Q02447
# COMPLEX:Q00653 Q02447
# COMPLEX:Q00653_Q04864 Q02447
# COMPLEX:Q01201_Q04206 Q02447
# COMPLEX:P05412_P15408 Q02447
# COMPLEX:P17275_P17535 Q02447
# COMPLEX:Q00653_Q01201 P42229
# COMPLEX:P19838_Q00653 P42229
# COMPLEX:Q00653_Q04206 P42229
# COMPLEX:P19838 P42229
# COMPLEX:Q04864 P42229
# COMPLEX:Q04206_Q04864 P42229
# COMPLEX:Q01201_Q04864 P42229
# COMPLEX:Q00653 P42229
# COMPLEX:Q00653_Q04864 P42229
# COMPLEX:Q01201_Q04206 P42229
# COMPLEX:Q00653_Q01201 P41235
# COMPLEX:P19838_Q00653 P41235
# COMPLEX:Q00653_Q04206 P41235
# COMPLEX:P19838 P41235
# COMPLEX:Q04864 P41235
# COMPLEX:Q04206_Q04864 P41235
# COMPLEX:Q01201_Q04864 P41235
# COMPLEX:Q00653 P41235
# COMPLEX:Q00653_Q04864 P41235
# COMPLEX:Q01201_Q04206 P41235
# looking for paths in the network with length:  0  for node  SRC  and  MAP4K4
# looking for paths in the network with length:  1  for node  SRC  and  MAP4K4
# looking for paths in the network with length:  2  for node  SRC  and  MAP4K4
# looking for paths in the network with length:  3  for node  SRC  and  MAP4K4
# i_search =  3
# Looking for paths with length:  0  for node  SRC  and  MAP4K4
# i_search =  3
# Looking for paths with length:  1  for node  SRC  and  MAP4K4
# i_search =  3
# Looking for paths with length:  2  for node  SRC  and  MAP4K4
# [['SRC', 'MAP3K2', 'MAP4K4'], ['SRC', 'EPHB1', 'MAP4K4'], ['SRC', 'PPARG', 'MAP4K4']]
# P12931 Q9Y2U5
# O95819 Q9Y2U5
# P12931 P54762
# P54762 O95819
# P12931 P37231
# P37231 O95819
# P12931 Q05397
# P12830 P12931
# P12931 P19022
# P12931 Q14289
# P02452 P12931
# COMPLEX:P05412_P53539 P12931
# COMPLEX:P19838_Q04206 P12931
# COMPLEX:P17535_P53539 P12931
# Q8WYK2 P12931
# P12931 P19838
# P12931 Q9NQB0
# COMPLEX:Q01201 P12931
# COMPLEX:P15408_P17275 P12931
# COMPLEX:P15407_P17535 P12931
# P08047 P12931
# COMPLEX:P01100_P17275 P12931
# COMPLEX:P19838_Q04864 P12931
# COMPLEX:Q04206 P12931
# COMPLEX:P19838_Q01201 P12931
# COMPLEX:P15407_P17275 P12931
# COMPLEX:P05412_P17275 P12931
# COMPLEX:P17535 P12931
# Q02447 P12931
# P12931 P42229
# COMPLEX:Q00653_Q01201 P12931
# COMPLEX:Q00653_Q01201 P42229
# COMPLEX:P19838_Q00653 P42229
# COMPLEX:Q00653_Q04206 P42229
# COMPLEX:P19838 P42229
# COMPLEX:Q04864 P42229
# COMPLEX:Q04206_Q04864 P42229
# COMPLEX:Q01201_Q04864 P42229
# COMPLEX:Q00653 P42229
# COMPLEX:Q00653_Q04864 P42229
# COMPLEX:Q01201_Q04206 P42229
# P37231 P42229
# COMPLEX:Q00653_Q01201 P41235
# COMPLEX:Q00653_Q01201 P37231
# COMPLEX:P17275_P53539 P37231
# COMPLEX:P19838_Q00653 P41235
# COMPLEX:P19838_Q00653 P37231
# COMPLEX:P15408_P17535 P37231
# COMPLEX:Q00653_Q04206 P41235
# COMPLEX:Q00653_Q04206 P37231
# COMPLEX:P19838 P41235
# COMPLEX:P19838 P37231
# COMPLEX:Q04864 P41235
# COMPLEX:Q04864 P37231
# COMPLEX:P05412_P17535 P37231
# COMPLEX:Q04206_Q04864 P41235
# COMPLEX:Q01201_Q04864 P41235
# COMPLEX:Q00653 P41235
# COMPLEX:Q00653_Q04864 P41235
# COMPLEX:Q01201_Q04206 P41235
# COMPLEX:P01100_P05412 P37231
# COMPLEX:P17275 P37231
# COMPLEX:P05412_P15407 P37231
# COMPLEX:P05412 P37231
# COMPLEX:P01100_P17535 P37231
# COMPLEX:Q04206_Q04864 P37231
# COMPLEX:Q01201_Q04864 P37231
# COMPLEX:Q00653 P37231
# COMPLEX:Q00653_Q04864 P37231
# COMPLEX:Q01201_Q04206 P37231
# COMPLEX:P05412_P15408 P37231
# COMPLEX:P17275_P17535 P37231
# looking for paths in the network with length:  0  for node  SRC  and  PTK2B
# looking for paths in the network with length:  1  for node  SRC  and  PTK2B
# Found a path!
# [['SRC', 'PTK2B']]
# looking for paths in the network with length:  0  for node  SRC  and  COL1A1
# looking for paths in the network with length:  1  for node  SRC  and  COL1A1
# Found a path!
# [['SRC', 'COL1A1']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  PTK2
# looking for paths in the network with length:  1  for node  NOTCH1  and  PTK2
# looking for paths in the network with length:  2  for node  NOTCH1  and  PTK2
# Found a path!
# [['NOTCH1', 'RELB', 'PTK2'], ['NOTCH1', 'COMPLEX:P19838_Q04864', 'PTK2'], ['NOTCH1', 'COMPLEX:Q00653_Q01201', 'PTK2'], ['NOTCH1', 'RELA', 'PTK2'], ['NOTCH1', 'NFKB1', 'PTK2'], ['NOTCH1', 'COMPLEX:Q00653_Q04206', 'PTK2'], ['NOTCH1', 'COMPLEX:P19838_Q04206', 'PTK2'], ['NOTCH1', 'COMPLEX:P19838_Q01201', 'PTK2'], ['NOTCH1', 'COMPLEX:Q04206_Q04864', 'PTK2'], ['NOTCH1', 'COMPLEX:P19838_Q00653', 'PTK2'], ['NOTCH1', 'REL', 'PTK2'], ['NOTCH1', 'COMPLEX:Q01201_Q04206', 'PTK2'], ['NOTCH1', 'COMPLEX:Q01201_Q04864', 'PTK2'], ['NOTCH1', 'NFKB2', 'PTK2'], ['NOTCH1', 'COMPLEX:Q00653_Q04864', 'PTK2']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  CDH1
# looking for paths in the network with length:  1  for node  NOTCH1  and  CDH1
# looking for paths in the network with length:  2  for node  NOTCH1  and  CDH1
# Found a path!
# [['NOTCH1', 'RELB', 'CDH1'], ['NOTCH1', 'COMPLEX:P19838_Q04864', 'CDH1'], ['NOTCH1', 'COMPLEX:Q00653_Q01201', 'CDH1'], ['NOTCH1', 'RELA', 'CDH1'], ['NOTCH1', 'PPARG', 'CDH1'], ['NOTCH1', 'NFKB1', 'CDH1'], ['NOTCH1', 'COMPLEX:Q00653_Q04206', 'CDH1'], ['NOTCH1', 'COMPLEX:P19838_Q04206', 'CDH1'], ['NOTCH1', 'COMPLEX:P19838_Q01201', 'CDH1'], ['NOTCH1', 'COMPLEX:Q04206_Q04864', 'CDH1'], ['NOTCH1', 'COMPLEX:P19838_Q00653', 'CDH1'], ['NOTCH1', 'REL', 'CDH1'], ['NOTCH1', 'COMPLEX:Q01201_Q04206', 'CDH1'], ['NOTCH1', 'COMPLEX:Q01201_Q04864', 'CDH1'], ['NOTCH1', 'NFKB2', 'CDH1'], ['NOTCH1', 'COMPLEX:Q00653_Q04864', 'CDH1']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  CDH2
# looking for paths in the network with length:  1  for node  NOTCH1  and  CDH2
# Found a path!
# [['NOTCH1', 'CDH2']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  VIM
# looking for paths in the network with length:  1  for node  NOTCH1  and  VIM
# looking for paths in the network with length:  2  for node  NOTCH1  and  VIM
# Found a path!
# [['NOTCH1', 'RELB', 'VIM'], ['NOTCH1', 'SP3', 'VIM'], ['NOTCH1', 'COMPLEX:P19838_Q04864', 'VIM'], ['NOTCH1', 'COMPLEX:Q00653_Q01201', 'VIM'], ['NOTCH1', 'RELA', 'VIM'], ['NOTCH1', 'NFKB1', 'VIM'], ['NOTCH1', 'SP1', 'VIM'], ['NOTCH1', 'COMPLEX:Q00653_Q04206', 'VIM'], ['NOTCH1', 'COMPLEX:P19838_Q04206', 'VIM'], ['NOTCH1', 'COMPLEX:P19838_Q01201', 'VIM'], ['NOTCH1', 'COMPLEX:Q04206_Q04864', 'VIM'], ['NOTCH1', 'COMPLEX:P19838_Q00653', 'VIM'], ['NOTCH1', 'REL', 'VIM'], ['NOTCH1', 'NFKB1', 'VIM'], ['NOTCH1', 'COMPLEX:Q01201_Q04206', 'VIM'], ['NOTCH1', 'COMPLEX:Q01201_Q04864', 'VIM'], ['NOTCH1', 'NFKB2', 'VIM'], ['NOTCH1', 'COMPLEX:Q00653_Q04864', 'VIM']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  MAP4K4
# looking for paths in the network with length:  1  for node  NOTCH1  and  MAP4K4
# looking for paths in the network with length:  2  for node  NOTCH1  and  MAP4K4
# Found a path!
# [['NOTCH1', 'PPARG', 'MAP4K4']]
# looking for paths in the network with length:  0  for node  NOTCH1  and  PTK2B
# looking for paths in the network with length:  1  for node  NOTCH1  and  PTK2B
# looking for paths in the network with length:  2  for node  NOTCH1  and  PTK2B
# looking for paths in the network with length:  3  for node  NOTCH1  and  PTK2B
# Found a path!
# [['NOTCH1', 'RELB', 'SRC', 'PTK2B'], ['NOTCH1', 'RELB', 'PTK2', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P15407_P17275', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P05412_P53539', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P05412_P17535', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P17275_P53539', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P05412_P15407', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P05412_P17275', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P01100_P17275', 'PTK2B'], ['NOTCH1', 'SP3', 'JUND', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P05412_P15408', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P01100_P05412', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P17535_P53539', 'PTK2B'], ['NOTCH1', 'SP3', 'SRC', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P15408_P17535', 'PTK2B'], ['NOTCH1', 'SP3', 'JUN', 'PTK2B'], ['NOTCH1', 'SP3', 'JUNB', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P15408_P17275', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P01100_P17535', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P15407_P17535', 'PTK2B'], ['NOTCH1', 'SP3', 'COMPLEX:P17275_P17535', 'PTK2B'], ['NOTCH1', 'COL1A1', 'SRC', 'PTK2B'], ['NOTCH1', 'COMPLEX:P19838_Q04864', 'SRC', 'PTK2B'], ['NOTCH1', 'COMPLEX:P19838_Q04864', 'PTK2', 'PTK2B'], ['NOTCH1', 'COMPLEX:Q00653_Q01201', 'SRC', 'PTK2B'], ['NOTCH1', 'COMPLEX:Q00653_Q01201', 'PTK2', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P15407_P17275', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P05412_P53539', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P05412_P17535', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P17275_P53539', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P05412_P15407', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P05412_P17275', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P01100_P17275', 'PTK2B'], ['NOTCH1', 'CDH2', 'JUND', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P05412_P15408', 'PTK2B'], ['NOTCH1', 'CDH2', 'COMPLEX:P01100_P05412', 'PTK2B'], ['NOTCH1', 
TK2B'], ['NOTCH1', 'SP1', 'COMPLEX:P05412_P15408', 'PTK2B'], ['NOTCH1', 'SP1', 'COMPLEX:P01100_P05412', 'PTK2B'], ['NOTCH1', 'SP1', 'COMPLEX:P17535_P53539', 'PTK2B'], ['NOTCH1', 'SP1', 'SRC', 'PTK2B'], ['NOTCH1', 'SP1', 'COMPLEX:P15408_P17535', 'PTK2B'], ['NO ...
# looking for paths in the network with length:  0  for node  NOTCH1  and  COL1A1
# looking for paths in the network with length:  1  for node  NOTCH1  and  COL1A1
# Found a path!
# [['NOTCH1', 'COL1A1']]
# looking for paths in the network with length:  0  for node  PTK2  and  CDH1
# looking for paths in the network with length:  1  for node  PTK2  and  CDH1
# looking for paths in the network with length:  2  for node  PTK2  and  CDH1
# Found a path!
# [['PTK2', 'RELB', 'CDH1'], ['PTK2', 'COMPLEX:P19838_Q04864', 'CDH1'], ['PTK2', 'COMPLEX:Q00653_Q01201', 'CDH1'], ['PTK2', 'SRC', 'CDH1'], ['PTK2', 'RELA', 'CDH1'], ['PTK2', 'NFKB1', 'CDH1'], ['PTK2', 'COMPLEX:Q00653_Q04206', 'CDH1'], ['PTK2', 'COMPLEX:P19838_Q04206', 'CDH1'], ['PTK2', 'COMPLEX:P19838_Q01201', 'CDH1'], ['PTK2', 'COMPLEX:Q04206_Q04864', 'CDH1'], ['PTK2', 'COMPLEX:P19838_Q00653', 'CDH1'], ['PTK2', 'REL', 'CDH1'], ['PTK2', 'COMPLEX:Q01201_Q04206', 'CDH1'], ['PTK2', 'COMPLEX:Q01201_Q04864', 'CDH1'], ['PTK2', 'NFKB2', 'CDH1'], ['PTK2', 'COMPLEX:Q00653_Q04864', 'CDH1']]
# looking for paths in the network with length:  0  for node  PTK2  and  CDH2
# looking for paths in the network with length:  1  for node  PTK2  and  CDH2
# looking for paths in the network with length:  2  for node  PTK2  and  CDH2
# Found a path!
# [['PTK2', 'RELB', 'CDH2'], ['PTK2', 'COMPLEX:P19838_Q04864', 'CDH2'], ['PTK2', 'COMPLEX:Q00653_Q01201', 'CDH2'], ['PTK2', 'SRC', 'CDH2'], ['PTK2', 'RELA', 'CDH2'], ['PTK2', 'NFKB1', 'CDH2'], ['PTK2', 'COMPLEX:Q00653_Q04206', 'CDH2'], ['PTK2', 'COMPLEX:P19838_Q04206', 'CDH2'], ['PTK2', 'COMPLEX:P19838_Q01201', 'CDH2'], ['PTK2', 'COMPLEX:Q04206_Q04864', 'CDH2'], ['PTK2', 'COMPLEX:P19838_Q00653', 'CDH2'], ['PTK2', 'REL', 'CDH2'], ['PTK2', 'COMPLEX:Q01201_Q04206', 'CDH2'], ['PTK2', 'COMPLEX:Q01201_Q04864', 'CDH2'], ['PTK2', 'NFKB2', 'CDH2'], ['PTK2', 'COMPLEX:Q00653_Q04864', 'CDH2']]
# looking for paths in the network with length:  0  for node  PTK2  and  VIM
# looking for paths in the network with length:  1  for node  PTK2  and  VIM
# looking for paths in the network with length:  2  for node  PTK2  and  VIM
# Found a path!
# [['PTK2', 'RELB', 'VIM'], ['PTK2', 'COMPLEX:P19838_Q04864', 'VIM'], ['PTK2', 'COMPLEX:Q00653_Q01201', 'VIM'], ['PTK2', 'RELA', 'VIM'], ['PTK2', 'NFKB1', 'VIM'], ['PTK2', 'COMPLEX:Q00653_Q04206', 'VIM'], ['PTK2', 'COMPLEX:P19838_Q04206', 'VIM'], ['PTK2', 'COMPLEX:P19838_Q01201', 'VIM'], ['PTK2', 'COMPLEX:Q04206_Q04864', 'VIM'], ['PTK2', 'COMPLEX:P19838_Q00653', 'VIM'], ['PTK2', 'REL', 'VIM'], ['PTK2', 'COMPLEX:Q01201_Q04206', 'VIM'], ['PTK2', 'COMPLEX:Q01201_Q04864', 'VIM'], ['PTK2', 'NFKB2', 'VIM'], ['PTK2', 'COMPLEX:Q00653_Q04864', 'VIM']]
# looking for paths in the network with length:  0  for node  PTK2  and  MAP4K4
# looking for paths in the network with length:  1  for node  PTK2  and  MAP4K4
# looking for paths in the network with length:  2  for node  PTK2  and  MAP4K4
# Found a path!
# [['PTK2', 'EPHB1', 'MAP4K4']]
# looking for paths in the network with length:  0  for node  PTK2  and  PTK2B
# looking for paths in the network with length:  1  for node  PTK2  and  PTK2B
# Found a path!
# [['PTK2', 'PTK2B']]
# looking for paths in the network with length:  0  for node  PTK2  and  COL1A1
# looking for paths in the network with length:  1  for node  PTK2  and  COL1A1
# looking for paths in the network with length:  2  for node  PTK2  and  COL1A1
# Found a path!
# [['PTK2', 'SRC', 'COL1A1']]
# looking for paths in the network with length:  0  for node  CDH1  and  CDH2
# looking for paths in the network with length:  1  for node  CDH1  and  CDH2
# looking for paths in the network with length:  2  for node  CDH1  and  CDH2
# Found a path!
# [['CDH1', 'COMPLEX:P15407_P17275', 'CDH2'], ['CDH1', 'COMPLEX:P05412_P53539', 'CDH2'], ['CDH1', 'COMPLEX:P05412_P17535', 'CDH2'], ['CDH1', 'COMPLEX:P17275_P53539', 'CDH2'], ['CDH1', 'COMPLEX:P05412_P15407', 'CDH2'], ['CDH1', 'COMPLEX:P05412_P17275', 'CDH2'], ['CDH1', 'COMPLEX:P01100_P17275', 'CDH2'], ['CDH1', 'NFKB1', 'CDH2'], ['CDH1', 'COMPLEX:P19838_Q04206', 'CDH2'], ['CDH1', 'JUND', 'CDH2'], ['CDH1', 'COMPLEX:P19838_Q00653', 'CDH2'], ['CDH1', 'REL', 'CDH2'], ['CDH1', 'COMPLEX:Q01201_Q04206', 'CDH2'], ['CDH1', 'COMPLEX:Q01201_Q04864', 'CDH2'], ['CDH1', 'NFKB2', 'CDH2'], ['CDH1', 'RELB', 'CDH2'], ['CDH1', 'COMPLEX:P05412_P15408', 'CDH2'], ['CDH1', 'COMPLEX:P19838_Q04864', 'CDH2'], ['CDH1', 'COMPLEX:Q00653_Q01201', 'CDH2'], ['CDH1', 'COMPLEX:P01100_P05412', 'CDH2'], ['CDH1', 'COMPLEX:P17535_P53539', 'CDH2'], ['CDH1', 'SRC', 'CDH2'], ['CDH1', 'COMPLEX:P15408_P17535', 'CDH2'], ['CDH1', 'JUN', 'CDH2'], ['CDH1', 'JUNB', 'CDH2'], ['CDH1', 'RELA', 'CDH2'], ['CDH1', 'PPARG', 'CDH2'], ['CDH1', 'COMPLEX:Q00653_Q04206', 'CDH2'], ['CDH1', 'COMPLEX:P19838_Q01201', 'CDH2'], ['CDH1', 'COMPLEX:P15408_P17275', 'CDH2'], ['CDH1', 'COMPLEX:P01100_P17535', 'CDH2'], ['CDH1', 'COMPLEX:Q04206_Q04864', 'CDH2'], ['CDH1', 'COMPLEX:P15407_P17535', 'CDH2'], ['CDH1', 'COMPLEX:P17275_P17535', 'CDH2'], ['CDH1', 'COMPLEX:Q00653_Q04864', 'CDH2']]
# looking for paths in the network with length:  0  for node  CDH1  and  VIM
# looking for paths in the network with length:  1  for node  CDH1  and  VIM
# looking for paths in the network with length:  2  for node  CDH1  and  VIM
# Found a path!
# [['CDH1', 'COMPLEX:P15407_P17275', 'VIM'], ['CDH1', 'COMPLEX:P05412_P53539', 'VIM'], ['CDH1', 'COMPLEX:P05412_P17535', 'VIM'], ['CDH1', 'COMPLEX:P17275_P53539', 'VIM'], ['CDH1', 'COMPLEX:P05412_P15407', 'VIM'], ['CDH1', 'COMPLEX:P05412_P17275', 'VIM'], ['CDH1', 'COMPLEX:P01100_P17275', 'VIM'], ['CDH1', 'NFKB1', 'VIM'], ['CDH1', 'COMPLEX:P19838_Q04206', 'VIM'], ['CDH1', 'JUND', 'VIM'], ['CDH1', 'COMPLEX:P19838_Q00653', 'VIM'], ['CDH1', 'REL', 'VIM'], ['CDH1', 'COMPLEX:Q01201_Q04206', 'VIM'], ['CDH1', 'COMPLEX:Q01201_Q04864', 'VIM'], ['CDH1', 'NFKB2', 'VIM'], ['CDH1', 'RELB', 'VIM'], ['CDH1', 'COMPLEX:P05412_P15408', 'VIM'], ['CDH1', 'COMPLEX:P19838_Q04864', 'VIM'], ['CDH1', 'COMPLEX:Q00653_Q01201', 'VIM'], ['CDH1', 'COMPLEX:P01100_P05412', 'VIM'], ['CDH1', 'COMPLEX:P17535_P53539', 'VIM'], ['CDH1', 'COMPLEX:P15408_P17535', 'VIM'], ['CDH1', 'JUN', 'VIM'], ['CDH1', 'JUNB', 'VIM'], ['CDH1', 'RELA', 'VIM'], ['CDH1', 'COMPLEX:Q00653_Q04206', 'VIM'], ['CDH1', 'COMPLEX:P19838_Q01201', 'VIM'], ['CDH1', 'COMPLEX:P15408_P17275', 'VIM'], ['CDH1', 'COMPLEX:P01100_P17535', 'VIM'], ['CDH1', 'COMPLEX:Q04206_Q04864', 'VIM'], ['CDH1', 'COMPLEX:P15407_P17535', 'VIM'], ['CDH1', 'COMPLEX:P17275_P17535', 'VIM'], ['CDH1', 'COMPLEX:Q00653_Q04864', 'VIM']]
# looking for paths in the network with length:  0  for node  CDH1  and  MAP4K4
# looking for paths in the network with length:  1  for node  CDH1  and  MAP4K4
# looking for paths in the network with length:  2  for node  CDH1  and  MAP4K4
# Found a path!
# [['CDH1', 'PPARG', 'MAP4K4']]
# looking for paths in the network with length:  0  for node  CDH1  and  PTK2B
# looking for paths in the network with length:  1  for node  CDH1  and  PTK2B
# looking for paths in the network with length:  2  for node  CDH1  and  PTK2B
# Found a path!
# [['CDH1', 'COMPLEX:P15407_P17275', 'PTK2B'], ['CDH1', 'COMPLEX:P05412_P53539', 'PTK2B'], ['CDH1', 'COMPLEX:P05412_P17535', 'PTK2B'], ['CDH1', 'COMPLEX:P17275_P53539', 'PTK2B'], ['CDH1', 'COMPLEX:P05412_P15407', 'PTK2B'], ['CDH1', 'COMPLEX:P05412_P17275', 'PTK2B'], ['CDH1', 'COMPLEX:P01100_P17275', 'PTK2B'], ['CDH1', 'JUND', 'PTK2B'], ['CDH1', 'COMPLEX:P05412_P15408', 'PTK2B'], ['CDH1', 'COMPLEX:P01100_P05412', 'PTK2B'], ['CDH1', 'COMPLEX:P17535_P53539', 'PTK2B'], ['CDH1', 'SRC', 'PTK2B'], ['CDH1', 'COMPLEX:P15408_P17535', 'PTK2B'], ['CDH1', 'JUN', 'PTK2B'], ['CDH1', 'JUNB', 'PTK2B'], ['CDH1', 'COMPLEX:P15408_P17275', 'PTK2B'], ['CDH1', 'COMPLEX:P01100_P17535', 'PTK2B'], ['CDH1', 'COMPLEX:P15407_P17535', 'PTK2B'], ['CDH1', 'COMPLEX:P17275_P17535', 'PTK2B']]
# looking for paths in the network with length:  0  for node  CDH1  and  COL1A1
# looking for paths in the network with length:  1  for node  CDH1  and  COL1A1
# looking for paths in the network with length:  2  for node  CDH1  and  COL1A1
# Found a path!
# [['CDH1', 'SRC', 'COL1A1']]
# looking for paths in the network with length:  0  for node  CDH2  and  VIM
# looking for paths in the network with length:  1  for node  CDH2  and  VIM
# looking for paths in the network with length:  2  for node  CDH2  and  VIM
# Found a path!
# [['CDH2', 'COMPLEX:P15407_P17275', 'VIM'], ['CDH2', 'COMPLEX:P05412_P53539', 'VIM'], ['CDH2', 'COMPLEX:P05412_P17535', 'VIM'], ['CDH2', 'COMPLEX:P17275_P53539', 'VIM'], ['CDH2', 'COMPLEX:P05412_P15407', 'VIM'], ['CDH2', 'COMPLEX:P05412_P17275', 'VIM'], ['CDH2', 'COMPLEX:P01100_P17275', 'VIM'], ['CDH2', 'NFKB1', 'VIM'], ['CDH2', 'COMPLEX:P19838_Q04206', 'VIM'], ['CDH2', 'JUND', 'VIM'], ['CDH2', 'COMPLEX:P19838_Q00653', 'VIM'], ['CDH2', 'REL', 'VIM'], ['CDH2', 'COMPLEX:Q01201_Q04206', 'VIM'], ['CDH2', 'COMPLEX:Q01201_Q04864', 'VIM'], ['CDH2', 'NFKB2', 'VIM'], ['CDH2', 'RELB', 'VIM'], ['CDH2', 'COMPLEX:P05412_P15408', 'VIM'], ['CDH2', 'COMPLEX:P19838_Q04864', 'VIM'], ['CDH2', 'COMPLEX:Q00653_Q01201', 'VIM'], ['CDH2', 'COMPLEX:P01100_P05412', 'VIM'], ['CDH2', 'COMPLEX:P17535_P53539', 'VIM'], ['CDH2', 'COMPLEX:P15408_P17535', 'VIM'], ['CDH2', 'JUN', 'VIM'], ['CDH2', 'JUNB', 'VIM'], ['CDH2', 'RELA', 'VIM'], ['CDH2', 'COMPLEX:Q00653_Q04206', 'VIM'], ['CDH2', 'COMPLEX:P19838_Q01201', 'VIM'], ['CDH2', 'COMPLEX:P15408_P17275', 'VIM'], ['CDH2', 'COMPLEX:P01100_P17535', 'VIM'], ['CDH2', 'COMPLEX:Q04206_Q04864', 'VIM'], ['CDH2', 'COMPLEX:P15407_P17535', 'VIM'], ['CDH2', 'COMPLEX:P17275_P17535', 'VIM'], ['CDH2', 'COMPLEX:Q00653_Q04864', 'VIM']]
# looking for paths in the network with length:  0  for node  CDH2  and  MAP4K4
# looking for paths in the network with length:  1  for node  CDH2  and  MAP4K4
# looking for paths in the network with length:  2  for node  CDH2  and  MAP4K4
# Found a path!
# [['CDH2', 'PPARG', 'MAP4K4']]
# looking for paths in the network with length:  0  for node  CDH2  and  PTK2B
# looking for paths in the network with length:  1  for node  CDH2  and  PTK2B
# looking for paths in the network with length:  2  for node  CDH2  and  PTK2B
# Found a path!
# [['CDH2', 'COMPLEX:P15407_P17275', 'PTK2B'], ['CDH2', 'COMPLEX:P05412_P53539', 'PTK2B'], ['CDH2', 'COMPLEX:P05412_P17535', 'PTK2B'], ['CDH2', 'COMPLEX:P17275_P53539', 'PTK2B'], ['CDH2', 'COMPLEX:P05412_P15407', 'PTK2B'], ['CDH2', 'COMPLEX:P05412_P17275', 'PTK2B'], ['CDH2', 'COMPLEX:P01100_P17275', 'PTK2B'], ['CDH2', 'JUND', 'PTK2B'], ['CDH2', 'COMPLEX:P05412_P15408', 'PTK2B'], ['CDH2', 'COMPLEX:P01100_P05412', 'PTK2B'], ['CDH2', 'COMPLEX:P17535_P53539', 'PTK2B'], ['CDH2', 'SRC', 'PTK2B'], ['CDH2', 'COMPLEX:P15408_P17535', 'PTK2B'], ['CDH2', 'JUN', 'PTK2B'], ['CDH2', 'JUNB', 'PTK2B'], ['CDH2', 'COMPLEX:P15408_P17275', 'PTK2B'], ['CDH2', 'COMPLEX:P01100_P17535', 'PTK2B'], ['CDH2', 'COMPLEX:P15407_P17535', 'PTK2B'], ['CDH2', 'COMPLEX:P17275_P17535', 'PTK2B']]
# looking for paths in the network with length:  0  for node  CDH2  and  COL1A1
# looking for paths in the network with length:  1  for node  CDH2  and  COL1A1
# looking for paths in the network with length:  2  for node  CDH2  and  COL1A1
# Found a path!
# [['CDH2', 'SRC', 'COL1A1'], ['CDH2', 'NOTCH1', 'COL1A1']]
# looking for paths in the network with length:  0  for node  VIM  and  MAP4K4
# looking for paths in the network with length:  1  for node  VIM  and  MAP4K4
# looking for paths in the network with length:  2  for node  VIM  and  MAP4K4
# looking for paths in the network with length:  3  for node  VIM  and  MAP4K4
# Found a path!
# [['VIM', 'STAT5A', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P15407_P17275', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P05412_P53539', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P05412_P17535', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P17275_P53539', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P05412_P15407', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P05412_P17275', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P01100_P17275', 'PPARG', 'MAP4K4'], ['VIM', 'NFKB1', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P19838_Q04206', 'PPARG', 'MAP4K4'], ['VIM', 'JUND', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P19838_Q00653', 'PPARG', 'MAP4K4'], ['VIM', 'REL', 'PPARG', 'MAP4K4'], ['VIM', 'NFKB1', 'MAP3K2', 'MAP4K4'], ['VIM', 'NFKB1', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q01201_Q04206', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q01201_Q04864', 'PPARG', 'MAP4K4'], ['VIM', 'NFKB2', 'PPARG', 'MAP4K4'], ['VIM', 'RELB', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P05412_P15408', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P19838_Q04864', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q00653_Q01201', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P01100_P05412', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P17535_P53539', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P15408_P17535', 'PPARG', 'MAP4K4'], ['VIM', 'JUN', 'PPARG', 'MAP4K4'], ['VIM', 'JUNB', 'PPARG', 'MAP4K4'], ['VIM', 'RELA', 'PPARG', 'MAP4K4'], ['VIM', 'SP1', 'EPHB1', 'MAP4K4'], ['VIM', 'SP1', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q00653_Q04206', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P19838_Q01201', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P15408_P17275', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P01100_P17535', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q04206_Q04864', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P15407_P17535', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:P17275_P17535', 'PPARG', 'MAP4K4'], ['VIM', 'COMPLEX:Q00653_Q04864', 'PPARG', 'MAP4K4']]
# looking for paths in the network with length:  0  for node  VIM  and  PTK2B
# looking for paths in the network with length:  1  for node  VIM  and  PTK2B
# looking for paths in the network with length:  2  for node  VIM  and  PTK2B
# Found a path!
# [['VIM', 'COMPLEX:P15407_P17275', 'PTK2B'], ['VIM', 'COMPLEX:P05412_P53539', 'PTK2B'], ['VIM', 'COMPLEX:P05412_P17535', 'PTK2B'], ['VIM', 'COMPLEX:P17275_P53539', 'PTK2B'], ['VIM', 'COMPLEX:P05412_P15407', 'PTK2B'], ['VIM', 'COMPLEX:P05412_P17275', 'PTK2B'], ['VIM', 'COMPLEX:P01100_P17275', 'PTK2B'], ['VIM', 'JUND', 'PTK2B'], ['VIM', 'COMPLEX:P05412_P15408', 'PTK2B'], ['VIM', 'COMPLEX:P01100_P05412', 'PTK2B'], ['VIM', 'COMPLEX:P17535_P53539', 'PTK2B'], ['VIM', 'COMPLEX:P15408_P17535', 'PTK2B'], ['VIM', 'JUN', 'PTK2B'], ['VIM', 'JUNB', 'PTK2B'], ['VIM', 'COMPLEX:P15408_P17275', 'PTK2B'], ['VIM', 'COMPLEX:P01100_P17535', 'PTK2B'], ['VIM', 'COMPLEX:P15407_P17535', 'PTK2B'], ['VIM', 'COMPLEX:P17275_P17535', 'PTK2B']]
# looking for paths in the network with length:  0  for node  VIM  and  COL1A1
# looking for paths in the network with length:  1  for node  VIM  and  COL1A1
# looking for paths in the network with length:  2  for node  VIM  and  COL1A1
# Found a path!
# [['VIM', 'SP3', 'COL1A1'], ['VIM', 'NFKB1', 'COL1A1'], ['VIM', 'SP1', 'COL1A1']]
# looking for paths in the network with length:  0  for node  MAP4K4  and  PTK2B
# looking for paths in the network with length:  1  for node  MAP4K4  and  PTK2B
# looking for paths in the network with length:  2  for node  MAP4K4  and  PTK2B
# looking for paths in the network with length:  3  for node  MAP4K4  and  PTK2B
# Found a path!
# [['MAP4K4', 'EPHB1', 'PTK2', 'PTK2B'], ['MAP4K4', 'EPHB1', 'SRC', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P15407_P17275', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P05412_P53539', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P05412_P17535', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P17275_P53539', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P05412_P15407', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P05412_P17275', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P01100_P17275', 'PTK2B'], ['MAP4K4', 'PPARG', 'JUND', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P05412_P15408', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P01100_P05412', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P17535_P53539', 'PTK2B'], ['MAP4K4', 'PPARG', 'SRC', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P15408_P17535', 'PTK2B'], ['MAP4K4', 'PPARG', 'JUN', 'PTK2B'], ['MAP4K4', 'PPARG', 'JUNB', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P15408_P17275', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P01100_P17535', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P15407_P17535', 'PTK2B'], ['MAP4K4', 'PPARG', 'COMPLEX:P17275_P17535', 'PTK2B'], ['MAP4K4', 'MAP3K2', 'SRC', 'PTK2B']]
# looking for paths in the network with length:  0  for node  MAP4K4  and  COL1A1
# looking for paths in the network with length:  1  for node  MAP4K4  and  COL1A1
# looking for paths in the network with length:  2  for node  MAP4K4  and  COL1A1
# looking for paths in the network with length:  3  for node  MAP4K4  and  COL1A1
# Found a path!
# [['MAP4K4', 'EPHB1', 'SP1', 'COL1A1'], ['MAP4K4', 'EPHB1', 'SRC', 'COL1A1'], ['MAP4K4', 'PPARG', 'NFKB1', 'COL1A1'], ['MAP4K4', 'PPARG', 'SRC', 'COL1A1'], ['MAP4K4', 'PPARG', 'NOTCH1', 'COL1A1'], ['MAP4K4', 'PPARG', 'SP1', 'COL1A1'], ['MAP4K4', 'MAP3K2', 'NFKB1', 'COL1A1'], ['MAP4K4', 'MAP3K2', 'SRC', 'COL1A1']]
# looking for paths in the network with length:  0  for node  PTK2B  and  COL1A1
# looking for paths in the network with length:  1  for node  PTK2B  and  COL1A1
# looking for paths in the network with length:  2  for node  PTK2B  and  COL1A1
# Found a path!
# [['PTK2B', 'SRC', 'COL1A1']]
# CPU times: user 2min 4s, sys: 36.8 ms, total: 2min 4s
# Wall time: 2min 4s

# %%
visualizer = NetworkVisualizer(new_net1, color_by='effect')
visualizer.render()

# %% [markdown]
# ### We can access the network object edges to explore which interactions are in our network

# %%
new_net1.edges
# Out:
#                        source  target                Type       Effect  \
# 8080                   P12931  Q05397  post_translational  stimulation
# 77863                  P12830  P12931  post_translational  stimulation
# 34553                  P12931  P19022  post_translational   inhibition
# 5786                   P12931  Q14289  post_translational  stimulation
# 106165                 P02452  P12931  post_translational  stimulation
# ...                       ...     ...                 ...          ...
# 147629         COMPLEX:Q00653  P37231     transcriptional   inhibition
# 147632  COMPLEX:Q00653_Q04864  P37231     transcriptional   inhibition
# 147626  COMPLEX:Q01201_Q04206  P37231     transcriptional   inhibition
# 140178  COMPLEX:P05412_P15408  P37231     transcriptional   inhibition
# 140179  COMPLEX:P17275_P17535  P37231     transcriptional   inhibition
#
#                                                References
# 8080    Adhesome:10085298;Adhesome:10592173;Adhesome:1...
# 77863   ACSN:16039586;ACSN:16099633;ACSN:17143292;ACSN...
# 34553   ACSN:15782139;ACSN:16371504;ACSN:16492141;ACSN...
# 5786    Adhesome:10329689;Adhesome:10521452;Adhesome:1...
# 106165                                                NaN
# ...                                                   ...
# 147629              CollecTRI:12732648;CollecTRI:14646597
# 147632              CollecTRI:12732648;CollecTRI:14646597
# 147626              CollecTRI:12732648;CollecTRI:14646597
# 140178              CollecTRI:11124825;CollecTRI:24464219
# 140179              CollecTRI:11124825;CollecTRI:24464219
#
# [394 rows x 5 columns]

# %% [markdown]
# ### Finally we can export the network in bnet format with some basic logical equations

# %%
from neko._outputs.exports import Exports

# %%
export = Exports(new_net1)

# %%
export.export_bnet()
export.export_sif()
# Out:
# The network has some undefined interaction that will be ignored. WARNING: this can result ina disconnected model!
# ['SET']

# %% [markdown]
# # TO DO:
#
# - method to print sif file with reference for each interaction (easy task)
# - more utility functions (???)

# %%
# %%time
new_net1.connect_genes_to_phenotype(id_accession="GO:0097194", phenotype="execution phase of apoptosis", only_signed=True, compress=True, maxlen=1)
# Out:
# Start requesting genes from Gene Ontology
# Fetching from:  https://golr-aux.geneontology.io/solr/select?defType=edismax&qt=standard&indent=on&wt=csv&rows=100000&start=0&fl=bioentity_label&facet=true&facet.mincount=1&facet.sort=count&json.nl=arrarr&facet.limit=25&hl=true&hl.simple.pre=%3Cem%20class=%22hilite%22%3E&hl.snippets=1000&csv.encapsulator=&csv.separator=%09&csv.header=false&csv.mv.separator=%7C&fq=document_category:%22annotation%22&fq=isa_partof_closure:%22GO:0097194%22&fq=taxon_subset_closure_label:%22Homo%20sapiens%22&fq=type:%22protein%22&fq=annotation_class_label:%22execution%20phase%20of%20apoptosis%22&facet.field=aspect&facet.field=taxon_subset_closure_label&facet.field=type&facet.field=evidence_subset_closure_label&facet.field=regulates_closure_label&facet.field=isa_partof_closure_label&facet.field=annotation_class_label&facet.field=qualifier&facet.field=annotation_extension_class_closure_label&facet.field=assigned_by&facet.field=panther_family_label&q=*:*
# Done
# Starting connecting network's nodes to:  ['AIFM3', 'CASP7', 'MADD', 'CASP3', 'CASP8', 'CASP5', 'BNIP1', 'CIDEC', 'COLEC11', 'HTRA2', 'CASP12', 'TAOK1', 'BBC3', 'CFLAR', 'CIDEB', 'NFKBIZ', 'CASP6', 'STK24', 'CASP4', 'AKT1', 'NPR2', 'CASP2', 'CECR2']
