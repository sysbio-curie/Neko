# %% [markdown]
# ## Build phosphoste network
#
# This notebook provides the code to create a network based on kinase-substrate interactions and the annotated effect of phosphorylation (based on PhosphositePlus) on the activity of the substrate.

# %%
# %%time
from neko.core.network import Network
from neko._visual.visualize_network import NetworkVisualizer
from neko._inputs.resources import Resources
#from neko._annotations.gene_ontology import Ontology
import omnipath as op
import pandas as pd
# Out:
# CPU times: user 14 µs, sys: 2 µs, total: 16 µs
# Wall time: 20 µs

# %% [markdown]
# ## 1. Specify kinase-substrate interaction file and phosphosite effect annotation
#
# In this example, both files we utilize are from PhosphositePlus.

# %%
kinase_int_file = ("/home/eirini/Documents/Git/neko/Kinase_Substrate_Dataset")
phospho_effect_file = ("/home/eirini/Documents/Git/neko/Regulatory_sites")

# %% [markdown]
# ## 2. Add interactions as a resource database
#
# The *_process_psp_interactions_* function parses the provided files to create an interaction database in the Omnipath format.

# %%
interactions = process_psp_interactions(kinase_int_file, phospho_effect_file, "rat", expand=True)
resources.add_database(interactions)
# Out:
# /tmp/ipykernel_41274/4112765230.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kinase_int_filtered['target'] = kinase_int_filtered['SUB_GENE'] + '_' + kinase_int_filtered['SUB_MOD_RSD']
# /tmp/ipykernel_41274/4112765230.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phospho_effect_filtered['MOD_RSD'] = phospho_effect_filtered['MOD_RSD'].apply(lambda x: x[:-2] if x.endswith('-p') else x)
# /tmp/ipykernel_41274/4112765230.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phospho_effect_filtered['Prot_site'] = phospho_effect_filtered['GENE'] + '_' + phospho_effect_filtered['MOD_RSD']

# %%
#inspect database
interactions
# Out:
#           source       target  is_directed  consensus_direction  \
# 0           Pak2  Map2k1_S298         True                False
# 3          Ikbkb   Nfkbia_S32         True                False
# 5          Ikbkb   Nfkbia_S36         True                False
# 8          Mapk8    Dlg4_S295         True                False
# 9          Mapk8   Nr3c1_S246         True                False
# ...          ...          ...          ...                  ...
# 1943  Atp1a1_S16       Atp1a1         True                False
# 1944  Atp1a1_S23       Atp1a1         True                False
# 1946    Akt1_T34         Akt1         True                False
# 1947  Pebp1_S153        Pebp1         True                False
# 1951  Mark2_T208        Mark2         True                False
#
#       consensus_stimulation  consensus_inhibition  is_stimulation  \
# 0                     False                 False               1
# 3                     False                 False               1
# 5                     False                 False               1
# 8                     False                 False               1
# 9                     False                 False               1
# ...                     ...                   ...             ...
# 1943                  False                 False               1
# 1944                  False                 False               1
# 1946                  False                 False               0
# 1947                  False                 False               1
# 1951                  False                 False               1
#
#       is_inhibition curation_effort references sources
# 0                 0             NaN        NaN     NaN
# 3                 0             NaN        NaN     NaN
# 5                 0             NaN        NaN     NaN
# 8                 0             NaN        NaN     NaN
# 9                 1             NaN        NaN     NaN
# ...             ...             ...        ...     ...
# 1943              1           False      False   False
# 1944              1           False      False   False
# 1946              1           False      False   False
# 1947              1           False      False   False
# 1951              0           False      False   False
#
# [664 rows x 11 columns]

# %% [markdown]
# ### 3. Define a set of phosphosites we are interested in

# %%
genes = ['SMAD3_S423', 'SMAD3_S425', 'TP53_S15', 'AKT1S1_T246', 'GSK3B_S9', 'GSK3B_S21', 'AKT1_S473', 'HSPB1_S78', 'HSPB1_S82', 'MAPK14_T180', 'MAPK14_Y182', 'MAP2K1_S218', 'MAP2K1_S222', 'RPS6KA1_S380', 'CREB1_S133', 'NFKBIA_S32', 'NFKBIA_S36', 'MTOR_S2448', 'JUN_S63', 'EGFR_Y1068', 'MAPK3_T202', 'MAPK3_Y204', 'PTPN11_Y542', 'STAT3_Y705', 'CHEK2_T68', 'RELA_S536', 'MARCKS_S170']

#genes = ['SMAD3_S423', 'SMAD3_S425', 'TP53_S15', 'AKT1S1_T246', 'GSK3B_S9', 'GSK3B_S21', 'AKT1_S473', 'HSPB1_S78']

# %% [markdown]
# ### 4. Build network

# %%
# %%time
new_net1 = Network(genes, resources=resources.interactions)

# %%
# %%time
new_net1.complete_connection(mode="ALL", maxlen=10, k_mean="extensive", only_signed=True, connect_node_when_first_introduced=True)

# %%
visualizer1 = NetworkVisualizer(new_net1, color_by='effect')
visualizer1.render(output_file='inp_prot_sites')
